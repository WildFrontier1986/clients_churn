# %% [markdown]
# <span style="color:purple"><font size="5"><b>Комментарий студента</b>\
#     \
# <font size="3">Привет, ревьюер!\
#     Раз уж в Практикуме заведено предлагать "общаться на ты", а я хочу написать тебе небольшое оповещение, то, предложу первым, если тебе это удобно).\
#     Cтолкнулся с тем, что в Практикуме не установлена библиотека "imbalanced-learn", поэтому все шаги (п. 3.4.3-3.4.5), опирающиеся на неё, я закомментировал, а результаты вычислений вставил картинками. Прошу расскоментировать их, если будет возможность пользоваться данной библиотекой.\
#     Желаю приятной проверки)</span>

# %% [markdown]
# <div class="alert alert-block alert-info">
# <b>Комментарий ревьюера:</b> Понял 👍 Молодец, что используешь сторонние библиотеки )
# </div>

# %% [markdown]
# Привет, Илья!) Меня зовут Дуолан 👋. Сегодня я буду проверять твой проект. Давай вместе доведем его до идеала😉
# <br> Желательно реагировать на каждый мой комментарий («исправил», «не понятно как исправить ошибку», ...)
# <br> Пожалуйста, не удаляй мои комментарии, они будут необходимы для повторного ревью.
#
# Комментарии будут в <font color='green'>зеленой</font>, <font color='blue'>синей</font> или <font color='red'>красной</font> рамках:
#
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Если все сделано отлично
# </div>
#
# <div class="alert alert-block alert-warning">
# <b>Совет:</b> Если можно немного улучшить
# </div>
#
# <div class="alert alert-block alert-danger">
# <b>Замечание:</b> Если требуются исправления
# </div>
#
# Работа не может быть принята с красными комментариями.
#
# -------------------
#
# Будет очень хорошо, если ты будешь помечать свои действия следующим образом:
#
# <div class="alert alert-block alert-info">
# <b>Комментарий студента:</b> ...
# </div>
#
# <div class="alert alert-block alert-info">
# <b>Изменения:</b> Были внесены следующие изменения ...
# </div>

# %% [markdown]
# # <font color='orange'>Общее впечатление</font>
# * Этот проект выполнен очень хорошо
# * Видно, что приложено много усилий
# * Молодец, что структурируешь ноутбук, приятно проверять такие работы.
# * У тебя чистый и лаконичный код
# * Мне было интересно читать твои промежуточные выводы
# * Твой уровень подачи материала находится на высоком уровне
# * Интересная статья про метрику AUC-ROC: <a href="https://dyakonov.org/2017/07/28/auc-roc-площадь-под-кривой-ошибок/">ссылка</a>.
# * Критических замечаний нет
# * Молодец, отличная работа!
# * Также я оставил несколько советов. Исправь их если останется время
# * Удачи в дальнейшем обучении 👋

# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подключение-необходимых-библиотек-и-модулей" data-toc-modified-id="Подключение-необходимых-библиотек-и-модулей-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подключение необходимых библиотек и модулей</a></span></li><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Открытие-и-изучение-данных-из-файла" data-toc-modified-id="Открытие-и-изучение-данных-из-файла-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Открытие и изучение данных из файла</a></span><ul class="toc-item"><li><span><a href="#Создание-и-изучение-датафрейма" data-toc-modified-id="Создание-и-изучение-датафрейма-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>Создание и изучение датафрейма</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Работа-с-таблицей" data-toc-modified-id="Работа-с-таблицей-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Работа с таблицей</a></span><ul class="toc-item"><li><span><a href="#Декомпозиция" data-toc-modified-id="Декомпозиция-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Декомпозиция</a></span></li><li><span><a href="#Исследовательский-анализ-данных" data-toc-modified-id="Исследовательский-анализ-данных-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Исследовательский анализ данных</a></span></li></ul></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследование-баланса-классов-и-обучение-модели-без-учёта-дисбаланса" data-toc-modified-id="Исследование-баланса-классов-и-обучение-модели-без-учёта-дисбаланса-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Исследование баланса классов и обучение модели без учёта дисбаланса</a></span><ul class="toc-item"><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Подготовка признаков</a></span><ul class="toc-item"><li><span><a href="#Кодирование-категориальных-переменных" data-toc-modified-id="Кодирование-категориальных-переменных-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Кодирование категориальных переменных</a></span></li><li><span><a href="#Формирование-базовых-таблиц-с-признаками" data-toc-modified-id="Формирование-базовых-таблиц-с-признаками-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Формирование базовых таблиц с признаками</a></span></li><li><span><a href="#Формирование-обучающих-выборок-(базы-знаний)" data-toc-modified-id="Формирование-обучающих-выборок-(базы-знаний)-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Формирование обучающих выборок (базы знаний)</a></span></li><li><span><a href="#Формирование-валидационной-и-тестовой-выборок" data-toc-modified-id="Формирование-валидационной-и-тестовой-выборок-3.1.4"><span class="toc-item-num">3.1.4&nbsp;&nbsp;</span>Формирование валидационной и тестовой выборок</a></span></li><li><span><a href="#Масштабирование-(стандартизация)-признаков" data-toc-modified-id="Масштабирование-(стандартизация)-признаков-3.1.5"><span class="toc-item-num">3.1.5&nbsp;&nbsp;</span>Масштабирование (стандартизация) признаков</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.1.6"><span class="toc-item-num">3.1.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследование-моделей" data-toc-modified-id="Исследование-моделей-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Исследование моделей</a></span><ul class="toc-item"><li><span><a href="#Создание-функции,-формирующей-обученные-модели" data-toc-modified-id="Создание-функции,-формирующей-обученные-модели-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Создание функции, формирующей обученные модели</a></span></li><li><span><a href="#Исследование-модели-решающего-дерева---DecisionTreeClassifier" data-toc-modified-id="Исследование-модели-решающего-дерева---DecisionTreeClassifier-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Исследование модели решающего дерева - DecisionTreeClassifier</a></span></li><li><span><a href="#Исследование-модели-случайного-леса---RandomForestClassifier" data-toc-modified-id="Исследование-модели-случайного-леса---RandomForestClassifier-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Исследование модели случайного леса - RandomForestClassifier</a></span></li><li><span><a href="#Исследование-модели-логистической-регрессии---LogisticRegression" data-toc-modified-id="Исследование-модели-логистической-регрессии---LogisticRegression-3.2.4"><span class="toc-item-num">3.2.4&nbsp;&nbsp;</span>Исследование модели логистической регрессии - LogisticRegression</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.2.5"><span class="toc-item-num">3.2.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-моделей-на-тестовой-выборке" data-toc-modified-id="Проверка-моделей-на-тестовой-выборке-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Проверка моделей на тестовой выборке</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-решающего-дерева---DecisionTreeClassifier" data-toc-modified-id="Проверка-модели-решающего-дерева---DecisionTreeClassifier-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Проверка модели решающего дерева - DecisionTreeClassifier</a></span></li><li><span><a href="#Проверка-модели-случайного-леса---RandomForestClassifier" data-toc-modified-id="Проверка-модели-случайного-леса---RandomForestClassifier-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Проверка модели случайного леса - RandomForestClassifier</a></span></li><li><span><a href="#Проверка-модели-логистической-регрессии---LogisticRegression" data-toc-modified-id="Проверка-модели-логистической-регрессии---LogisticRegression-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Проверка модели логистической регрессии - LogisticRegression</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Проверка-модели-на-адекватность" data-toc-modified-id="Проверка-модели-на-адекватность-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Проверка модели на адекватность</a></span><ul class="toc-item"><li><span><a href="#Проверка-модели-model_random_forest" data-toc-modified-id="Проверка-модели-model_random_forest-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Проверка модели model_random_forest</a></span></li><li><span><a href="#Создание-и-проверка-модели-DummyClassifier" data-toc-modified-id="Создание-и-проверка-модели-DummyClassifier-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Создание и проверка модели DummyClassifier</a></span></li><li><span><a href="#Создание-синтетических-обучающих-выборок-SMOTENC" data-toc-modified-id="Создание-синтетических-обучающих-выборок-SMOTENC-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Создание синтетических обучающих выборок SMOTENC</a></span></li><li><span><a href="#Создание-и-проверка-модели-model_random_forest_sm" data-toc-modified-id="Создание-и-проверка-модели-model_random_forest_sm-3.4.4"><span class="toc-item-num">3.4.4&nbsp;&nbsp;</span>Создание и проверка модели model_random_forest_sm</a></span></li><li><span><a href="#Создание-и-проверка-модели-model_dummy_sm" data-toc-modified-id="Создание-и-проверка-модели-model_dummy_sm-3.4.5"><span class="toc-item-num">3.4.5&nbsp;&nbsp;</span>Создание и проверка модели model_dummy_sm</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-3.4.6"><span class="toc-item-num">3.4.6&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом-классов" data-toc-modified-id="Борьба-с-дисбалансом-классов-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Борьба с дисбалансом классов</a></span><ul class="toc-item"><li><span><a href="#Исследование-параметра-class_weight" data-toc-modified-id="Исследование-параметра-class_weight-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Исследование параметра class_weight</a></span></li><li><span><a href="#Разделение-признаков-обучающих-выборок-по-классам" data-toc-modified-id="Разделение-признаков-обучающих-выборок-по-классам-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Разделение признаков обучающих выборок по классам</a></span></li><li><span><a href="#Исследование-результатов-увеличенния-обучающих-данных" data-toc-modified-id="Исследование-результатов-увеличенния-обучающих-данных-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>Исследование результатов увеличенния обучающих данных</a></span><ul class="toc-item"><li><span><a href="#Формирование-увеличенных-обучающих-данных-(upsampling)" data-toc-modified-id="Формирование-увеличенных-обучающих-данных-(upsampling)-4.3.1"><span class="toc-item-num">4.3.1&nbsp;&nbsp;</span>Формирование увеличенных обучающих данных (upsampling)</a></span></li><li><span><a href="#Исследование-модели-решающего-дерева---DecisionTreeClassifier" data-toc-modified-id="Исследование-модели-решающего-дерева---DecisionTreeClassifier-4.3.2"><span class="toc-item-num">4.3.2&nbsp;&nbsp;</span>Исследование модели решающего дерева - DecisionTreeClassifier</a></span></li><li><span><a href="#Исследование-модели-случайного-леса---RandomForestClassifier" data-toc-modified-id="Исследование-модели-случайного-леса---RandomForestClassifier-4.3.3"><span class="toc-item-num">4.3.3&nbsp;&nbsp;</span>Исследование модели случайного леса - RandomForestClassifier</a></span></li><li><span><a href="#Исследование-модели-логистической-регрессии---LogisticRegression" data-toc-modified-id="Исследование-модели-логистической-регрессии---LogisticRegression-4.3.4"><span class="toc-item-num">4.3.4&nbsp;&nbsp;</span>Исследование модели логистической регрессии - LogisticRegression</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.3.5"><span class="toc-item-num">4.3.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li><li><span><a href="#Исследование-результатов-уменьшения-обучающих-данных" data-toc-modified-id="Исследование-результатов-уменьшения-обучающих-данных-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Исследование результатов уменьшения обучающих данных</a></span><ul class="toc-item"><li><span><a href="#Формирование-уменьшенных-обучающих-данных-(downsampling)" data-toc-modified-id="Формирование-уменьшенных-обучающих-данных-(downsampling)-4.4.1"><span class="toc-item-num">4.4.1&nbsp;&nbsp;</span>Формирование уменьшенных обучающих данных (downsampling)</a></span></li><li><span><a href="#Исследование-модели-решающего-дерева---DecisionTreeClassifier" data-toc-modified-id="Исследование-модели-решающего-дерева---DecisionTreeClassifier-4.4.2"><span class="toc-item-num">4.4.2&nbsp;&nbsp;</span>Исследование модели решающего дерева - DecisionTreeClassifier</a></span></li><li><span><a href="#Исследование-модели-случайного-леса---RandomForestClassifier" data-toc-modified-id="Исследование-модели-случайного-леса---RandomForestClassifier-4.4.3"><span class="toc-item-num">4.4.3&nbsp;&nbsp;</span>Исследование модели случайного леса - RandomForestClassifier</a></span></li><li><span><a href="#Исследование-модели-логистической-регрессии---LogisticRegression" data-toc-modified-id="Исследование-модели-логистической-регрессии---LogisticRegression-4.4.4"><span class="toc-item-num">4.4.4&nbsp;&nbsp;</span>Исследование модели логистической регрессии - LogisticRegression</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-4.4.5"><span class="toc-item-num">4.4.5&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Тестирование модели</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Тестирование-модели-model_upsampled_forest" data-toc-modified-id="Тестирование-модели-model_upsampled_forest-5.0.1"><span class="toc-item-num">5.0.1&nbsp;&nbsp;</span>Тестирование модели model_upsampled_forest</a></span></li><li><span><a href="#Вывод" data-toc-modified-id="Вывод-5.0.2"><span class="toc-item-num">5.0.2&nbsp;&nbsp;</span>Вывод</a></span></li></ul></li></ul></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Построение модели предсказания оттока клиентов

# %% [markdown]
# **Из «Бета-Банка» стали уходить клиенты. Каждый месяц. Немного, но заметно. Банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.\
# \
# Нужно спрогнозировать, уйдёт клиент из банка в ближайшее время или нет, на основании предоставленых исторических данных о поведении клиентов и расторжении договоров с банком.\
# \
# Необходимо построить модель с предельно большим значением *F1*-меры. Довести метрику до 0.59. Проверить *F1*-меру на тестовой выборке.\
# \
# Дополнительно измерять *AUC-ROC*, сравнивать её значение с *F1*-мерой.\
# \
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)**

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отличное введение 👍 Важно чтобы в проектах было подробное описание: когда потенциальные работодатели будут смотреть твой проект в портфолио, им нужно будет понимать задачу, чтобы можно было оценить её решение :) Молодец, что описание пишешь своими словами, не копируешь дословно описание проекта для студентов, так оно не выглядит как инструкция, а работа выглядит более самостоятельной.
# </div>

# %% [markdown]
# ## Подключение необходимых библиотек и модулей

# %%
# 1. Подключение модуля pathlib
import pathlib
# 2. Подключение класса Path модуля pathlib
from pathlib import Path
# 3. Подключение модуля warnings
import warnings

# 4. Подключение библиотеки Pandas
import pandas as pd
# 5. Подключение библиотеки numpy
import numpy as np
# 6. Подключение библиотеки scikit-learn
import sklearn
# 7. Подключение библиотеки imbalanced-learn
# import imblearn
# 8. Подключение библиотеки seaborn
import seaborn as sns

# 9. Подключение модуля matplotlib.pyplot
import matplotlib.pyplot as plt
# 10. Подключение модуля tree библиотеки scikit-learn
from sklearn import tree
# 11. Подключение модели DecisionTreeClassifier
# из модуля sklearn.tree
from sklearn.tree import DecisionTreeClassifier
# 12. Подключение модели RandomForestClassifier
# из модуля sklearn.ensemble
from sklearn.ensemble import RandomForestClassifier
# 13. Подключение модели LogisticRegression
# из модуля sklearn.linear_model
from sklearn.linear_model import LogisticRegression
# 14. Подключение функции train_test_split()
# из модуля sklearn.model_selection
from sklearn.model_selection import train_test_split
# 15. Подключение функций accuracy_score(), recall_score(),
# precision_score(), f1_score(), precision_recall_curve(),
# roc_curve(), roc_auc_score(), confusion_matrix(),
# ConfusionMatrixDisplay(), classification_report()
# из модуля sklearn.metrics
from sklearn.metrics import (
    accuracy_score,
    recall_score,
    precision_score,
    f1_score,
    precision_recall_curve,
    roc_curve,
    roc_auc_score,
    confusion_matrix,
    ConfusionMatrixDisplay,
    classification_report
)
# 16. Подключение модели DummyClassifier
# из модуля sklearn.dummy
from sklearn.dummy import DummyClassifier
# 17. Подключение модели StandardScaler
# из модуля sklearn.preprocessing
from sklearn.preprocessing import StandardScaler
# 18. Подключение функции shuffle()
# из модуля sklearn.utils
from sklearn.utils import shuffle
# 19. Подключение классов SMOTE и SMOTENC
# из модуля imblearn.over_sampling
# from imblearn.over_sampling import SMOTE, SMOTENC

# %%
# Снятие ограничения на количество выводимых колонок
pd.set_option('display.max_columns', None)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Правильное решение — выделять отдельную ячейку в начале проекта под подключение библиотек и настройки. Tак код легче поддерживать 👌
# </div>

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Открытие и изучение данных из файла

# %% [markdown]
# #### Создание и изучение датафрейма

# %%
# Формирование и открытие датафрейма df
try:
    df = pd.read_csv('/datasets/Churn.csv')
    display(df)
except:
    df = pd.read_csv(
        Path(
            pathlib.Path.cwd(),
            'datasets',
            'Churn.csv'
        )
    )
    display(df)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Вывод общей информации по датафрейму df
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 2.1.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Датафрейм содержит 10000 строк и 14 колонок.\
#     2. Названия колонок написаны с нарушением змеиного стиля. Необходимо исправить.\
#     3. Колонка 'RowNumber' дублирует индексы со смещением вверх на 1. Колонку можно удалить.\
#     4. Колонки 'CustomerId' и 'Surname' содержат личную информацию в виде категориальных переменных и не влияют на процесс обучения модели. Поэтому эти колонки можно удалить.</b></span></div>

# %%
# Вывод количества пропусков
df.isna().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# Exited               0
# dtype: int64

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 2.1.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Пропуски обнаружены в колонке 'Tenure' в количестве 909 шт.\
#     Возможно произошёл технический сбой при переносе данных. Лучше уточнить данные у дата-инженера или заказчика.\
#     2. Для минимизации искажения данных в процессе обучения модели можно выполнить порядковое кодирование (Ordinal Encoding) колонки 'Tenure'.\
#     3. В данном случае указан источник исходного датасета [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling). Скачаю для анализа датасет и размещу в 'Google Таблицах' с предоставлением доступа всем, у кого есть ссылка.</b></span></div>

# %%
# Формирование и открытие датафрейма df_new
try:
    df_new = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vTIxG8pr9RrEFb5BJkOUlHkLO2k4YMPLc0Sc9EfUYQK7aEF2c_Et9pCyn--n-8Qlrl1mLwF9TQ37u8d/pub?output=csv')
    display(df_new)
except:
    df_new = pd.read_csv(
        Path(
            pathlib.Path.cwd(),
            'datasets',
            'churn_modeling.csv'
        )
    )
    display(df_new)
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0             1    15634602   Hargrave          619    France  Female   42
# 1             2    15647311       Hill          608     Spain  Female   41
# 2             3    15619304       Onio          502    France  Female   42
# 3             4    15701354       Boni          699    France  Female   39
# 4             5    15737888   Mitchell          850     Spain  Female   43
# ...         ...         ...        ...          ...       ...     ...  ...
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# ...

# %%
# Вывод общей информации по датафрейму df_new
df_new.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %%
# Вывод списка характерных значений
df_new.describe()
# Out:
#          RowNumber    CustomerId   CreditScore           Age        Tenure  \
# count  10000.00000  1.000000e+04  10000.000000  10000.000000  10000.000000
# mean    5000.50000  1.569094e+07    650.528800     38.921800      5.012800
# std     2886.89568  7.193619e+04     96.653299     10.487806      2.892174
# min        1.00000  1.556570e+07    350.000000     18.000000      0.000000
# 25%     2500.75000  1.562853e+07    584.000000     32.000000      3.000000
# 50%     5000.50000  1.569074e+07    652.000000     37.000000      5.000000
# 75%     7500.25000  1.575323e+07    718.000000     44.000000      7.000000
# max    10000.00000  1.581569e+07    850.000000     92.000000     10.000000
#
#              Balance  NumOfProducts    HasCrCard  IsActiveMember  \
# count   10000.000000   10000.000000  10000.00000    10000.000000
# mean    76485.889288       1.530200      0.70550        0.515100
# std     62397.405202       0.581654      0.45584        0.499797
# ...

# %%
# Поиск явных дубликатов
df_new.duplicated().sum()
# Out:
# 0

# %%
# Вывод списка значений колонки 'Geografy'
df_new['Geography'].value_counts()
# Out:
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64

# %%
# Вывод списка значений колонки 'Gender'
df_new['Gender'].value_counts()
# Out:
# Male      5457
# Female    4543
# Name: Gender, dtype: int64

# %%
# Вывод списка значений колонки 'Exited'
# в долях по процентам
df_new['Exited'].value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Датафрейм содержит 10000 строк и 14 колонок.\
#     2. Названия колонок написаны с нарушением змеиного стиля. Необходимо исправить.\
#     3. Колонка 'RowNumber' дублирует индексы со смещением вверх на 1. Колонку можно удалить.\
#     4. Колонки 'CustomerId' и 'Surname' содержат личную информацию в виде категориальных переменных и не влияют на процесс обучения модели. Поэтому эти колонки можно удалить.\
#     5. Пропуски обнаружены в колонке 'Tenure' в количестве 909 шт.\
#     Возможно произошёл технический сбой при переносе данных.\
#     Источник исходного датасета [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling) позволил восстановить пропуски.\
#     6. Аномалии и явные дубликаты не обнаружены.\
#     7.1. В колонках представлены категориальные и численные данные.\
#     7.2. Категориальные данные заменим на численные с помощью прямого кодирования (One-Hot Encoding), удаляя первую колонку во избежание ловушки фиктивных признаков (дамми-ловушек).\
#     7.3. Так как данные в колонках 'CreditScore', 'Age', 'Tenure', 'Balance', 'EstimatedSalary' имеют разный размер, то необходимо выполнить стандартизацию (масштабирование).\
#     8. В колонке 'Exited' содержатся два значения 0 (ноль - нет) и 1 (единица - да), показывающие факт ухода клиента из банка.\
#     Наблюдается дисбаланс классов: 20% - единицы; 80% - ноли.\
#     Так как целевой признак категориальный, а самих признаков два, то решается задача бинарной классификации.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Ты хорошо владеешь методами первичного изучения данных 👍 Спасибо за информативный вывод
# </div>

# %% [markdown]
# ### Работа с таблицей

# %% [markdown]
# #### Декомпозиция

# %%
# Декомпозиция датафрейма df_new
df_decomp = df_new.drop(columns=['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Правильно эти столбцы не пригодятся для обучения моделей 👍
# </div>

# %%
# Переименование колонок в датафрейме df_decomp
df_decomp.rename(
    columns={
        'CreditScore': 'credit_score',
        'Geography': 'geography',
        'Gender': 'gender',
        'Age': 'age',
        'Tenure': 'tenure',
        'Balance': 'balance',
        'NumOfProducts': 'num_of_products',
        'HasCrCard': 'has_cr_card',
        'IsActiveMember': 'is_active_member',
        'EstimatedSalary': 'estimated_salary',
        'Exited': 'exited'
    },
    inplace=True
)

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Работать с такими названиями гораздо удобнее) Посмотри на такой вариант ниже. Здесь мы используем regex (регулярные выражения)
#
# Полезная <a href='https://habr.com/ru/post/545150/'>статья</a> про regex для начала
#
# Этот блогер хорошо объясняет в своем <a href='https://www.youtube.com/watch?v=sHw5hLYFaIw&t=247s'>видео</a>
# </div>
#
# ```python
# df.columns = df.columns.str.replace(r"([A-Z])", r" \1").str.lower().str.replace(' ', '_').str[1:]
# ```

# %%
# Перевод прописных букв в строчные в
# колонках 'geography' и 'gender'
df_decomp['geography'] = df_decomp['geography'].str.lower()
df_decomp['gender'] = df_decomp['gender'].str.lower()

# %%
# Вывод первых пяти строк df_decomp
df_decomp.head()
# Out:
#    credit_score geography  gender  age  tenure    balance  num_of_products  \
# 0           619    france  female   42       2       0.00                1
# 1           608     spain  female   41       1   83807.86                1
# 2           502    france  female   42       8  159660.80                3
# 3           699    france  female   39       1       0.00                2
# 4           850     spain  female   43       2  125510.82                1
#
#    has_cr_card  is_active_member  estimated_salary  exited
# 0            1                 1         101348.88       1
# 1            0                 1         112542.58       0
# 2            1                 0         113931.57       1
# 3            0                 0          93826.63       0
# 4            1                 1          79084.10       0

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 2.2.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Декомпозиция и переименование колонок датафрейма выполнены успешно.</b></span></div>

# %% [markdown]
# #### Исследовательский анализ данных

# %%
# Формирование датафрейма df_box для анализа
# выбросов с помощью ящика с 'усами'
df_box = df_decomp.loc[:, ['credit_score', 'age', 'tenure', 'balance', 'estimated_salary']]

# %%
# Вывод первых пяти строк df_box
df_box.head()
# Out:
#    credit_score  age  tenure    balance  estimated_salary
# 0           619   42       2       0.00         101348.88
# 1           608   41       1   83807.86         112542.58
# 2           502   42       8  159660.80         113931.57
# 3           699   39       1       0.00          93826.63
# 4           850   43       2  125510.82          79084.10

# %%
# Формирование списка названий колонок для
# цикла, строящего диаграммы размаха
columns_name = list(df_box.columns)

# %%
# Цикл построения диаграмм размаха
for name in columns_name:
    plt.figure(figsize=(5, 10))
    sns.boxplot(data=df_box[name])
    plt.title(f'ДИАГРАММА РАЗМАХА {name.upper()}')
    plt.grid(visible=True)
    plt.ylim()
    plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 2.2.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Аномальные выбросы не обнаружены.\
#     В колонках 'credit_score' и 'age' есть незначительные выбросы, но они адекватные, поэтому оставляю их.</b></span></div>

# %% [markdown]
# ### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Декомпозиция и переименование колонок датафрейма выполнены успешно.\
#     2. Аномальные выбросы не обнаружены.\
#     В колонках 'credit_score' и 'age' есть незначительные выбросы, но они адекватные, поэтому оставляю их.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Отлично, что провел проверку на аномалии 👍
# </div>

# %% [markdown]
# ## Исследование баланса классов и обучение модели без учёта дисбаланса

# %% [markdown]
# ### Подготовка признаков

# %% [markdown]
# #### Кодирование категориальных переменных

# %%
# Прямое кодирование (One-Hot Encoding) категориальных
# переменных в колонках 'geography' и 'gender'
df_ohe = pd.get_dummies(data=df_decomp, columns=['geography', 'gender'], drop_first=True)

# %%
# Вывод первых пяти строк df_ohe
df_ohe.head()
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  exited  geography_germany  \
# 0                 1         101348.88       1                  0
# 1                 1         112542.58       0                  0
# 2                 0         113931.57       1                  0
# 3                 0          93826.63       0                  0
# 4                 1          79084.10       0                  0
#
#    geography_spain  gender_male
# 0                0            0
# 1                1            0
# 2                0            0
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.1.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Кодирование категориальных данных в численные выполнено успешно.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> В данном случае это наиболее подходящий способ закодировать категориальные колонки 👍
# </div>

# %% [markdown]
# #### Формирование базовых таблиц с признаками

# %%
# Формирование общего датафрейма с признаками features
features = df_ohe.drop(columns='exited', axis=1)

# %%
# Вывод первых пяти строк features
features.head()
# Out:
#    credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 0           619   42       2       0.00                1            1
# 1           608   41       1   83807.86                1            0
# 2           502   42       8  159660.80                3            1
# 3           699   39       1       0.00                2            0
# 4           850   43       2  125510.82                1            1
#
#    is_active_member  estimated_salary  geography_germany  geography_spain  \
# 0                 1         101348.88                  0                0
# 1                 1         112542.58                  0                1
# 2                 0         113931.57                  0                0
# 3                 0          93826.63                  0                0
# 4                 1          79084.10                  0                1
#
#    gender_male
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0

# %%
# Формирование общего Series с целевыми признаками target
target = df_ohe['exited']

# %%
# Вывод первых пяти строк target
target.head()
# Out:
# 0    1
# 1    0
# 2    1
# 3    0
# 4    0
# Name: exited, dtype: int64

# %% [markdown]
# #### Формирование обучающих выборок (базы знаний)

# %% [markdown]
# **Так как функция `train_test_split()` разбивает исходный датафрейм на две выборки, а для заверщающего контроля нужна тестовая выборка и общая пропорция 3:1:1, то разбиваю базы данных `features` и `target` с запасом 40% под валидационную и тестовую выборки в пропорции 60%-40%.**

# %%
# Формирование обучающей выборки признаков (вопросов) features_train
# и целевых признаков (ответов) target_train
features_train, features_add, target_train, target_add = train_test_split(
    features,
    target,
    test_size=.4,
    random_state=777
)

# %%
# Вывод размера features_train
features_train.shape
# Out:
# (6000, 11)

# %%
# Вывод размера target_train
len(target_train)
# Out:
# 6000

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.1.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Обучающие выборки сформированы.</b></span></div>

# %% [markdown]
# #### Формирование валидационной и тестовой выборок

# %%
# Формирование валидационной и тестовой выборок признаков (вопросов) features_valid
# и features_test и целевых признаков (ответов) target_valid и target_test
features_valid, features_test, target_valid, target_test = train_test_split(
    features_add,
    target_add,
    test_size=.5,
    random_state=777
)

# %%
# Вывод размера features_valid
features_valid.shape
# Out:
# (2000, 11)

# %%
# Вывод размера target_valid
len(target_valid)
# Out:
# 2000

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.1.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Валидационная и тестовая выборки сформированы.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Данные поделены в адекватных пропорциях 👌 Молодец, что смотришь на размеры выборок после разбиения )
# </div>

# %% [markdown]
# #### Масштабирование (стандартизация) признаков

# %%
# Формирование списка колонок df_ohe,
# подлежащих стандартизации
for_scaler = ['credit_score', 'age', 'tenure', 'balance', 'estimated_salary']

# %%
# Формирование структуры для стандартизации данных
scaler = StandardScaler()

# %%
# Запуск обучения структуры scaler на выборке features_train
# по списку for_scaler
scaler.fit(features_train[for_scaler])
# Out:
# StandardScaler()

# %%
# Отключение предупреждения 'A value is trying to be set
# on a copy of a slice from a DataFrame.'
pd.options.mode.chained_assignment = None

# %%
# Стандартизация обучающей, валидационной и тестовой
# выборок признаков (вопросов) функцией transform()
features_train[for_scaler] = scaler.transform(features_train[for_scaler])
features_valid[for_scaler] = scaler.transform(features_valid[for_scaler])
features_test[for_scaler] = scaler.transform(features_test[for_scaler])

# %%
# Вывод первых пяти строк features_train
features_train.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 6263     -2.106401 -0.180821 -0.710656 -1.223063                2
# 5065      1.867017 -1.130181  1.717357  0.352704                1
# 2334      1.569268 -0.180821 -1.404374 -1.223063                2
# 2353     -0.987273 -1.225117  0.676780  0.257072                2
# 717       0.522010  0.293858 -0.016938 -1.223063                2
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 6263            1                 1          1.383332                  0
# 5065            1                 0         -1.220873                  0
# 2334            0                 0         -1.630591                  0
# 2353            1                 0          1.605105                  0
# 717             0                 0         -1.337938                  0
#
#       geography_spain  gender_male
# 6263                0            1
# 5065                0            0
# ...

# %%
# Вывод первых пяти строк features_valid
features_valid.head()
# Out:
#       credit_score       age    tenure   balance  num_of_products  \
# 6450      1.887552 -1.035245  0.329921 -1.223063                1
# 8601     -0.104291  0.578666  1.023639  0.704345                1
# 8309      1.014837 -1.130181  1.370498 -1.223063                2
# 6791     -0.514980  0.009051  0.676780  0.191070                2
# 6135     -1.572505 -0.180821  1.023639  0.833150                2
#
#       has_cr_card  is_active_member  estimated_salary  geography_germany  \
# 6450            1                 0         -0.463282                  0
# 8601            0                 0          1.647273                  1
# 8309            1                 0          0.557572                  0
# 6791            1                 0         -0.736719                  1
# 6135            1                 1          1.097395                  0
#
#       geography_spain  gender_male
# 6450                0            0
# 8601                0            1
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.1.4:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Стандартизация обучающей, валидационной и тестовой выборок выполнена успешно.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> Масштабирование сделано правильно - после разбиения данных, и scaler обучен на тренировочной выборке
# </div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>После кодирования категориальных переменных в числовые и формирования базовых таблиц успешно сформированы обучающая, валидационная и тестовая выборки, в которых выполнена стандартизация (масштабирование) данных в ряде колонок.\
#     Можно приступать к исследованию моделей машинного обучения.</b></span></div>

# %% [markdown]
# ### Исследование моделей

# %% [markdown]
# #### Создание функции, формирующей обученные модели

# %%
# Создание функции model_select(), обучающей модели
# для задач классификации с перебором параметров и
# метриками качества
# 1. Объявление функции model_select() и задание
# параметров данной функции
def model_select(
    model_name,
    features_train_income,
    target_train_income,
    features_valid_income,
    target_valid_income,
    depth_treshold=None,
    estimators_treshold=None,
    estimators_step=None,
    iter_start=None,
    iter_treshold=None,
    solver_used='lbfgs',
    class_weight_income=None,
    best_f1=0.2
):
    # A.2.1. Логическое условие для отбора и обучения
    # модели решающего дерева
    if model_name == DecisionTreeClassifier:
        # A.2.2 Создание переменной, содержащей список списков для
        # заполнения значениями максимальной глубины дерева,
        # минимального количества выборок в листьях, метрик
        # качества из списка
        data_value = []
        # A.2.3. Создание переменной со списком названий колонок
        columns_name = [
            'depth_value',
            'leaf_value',
            'accuracy_train',
            'accuracy_valid',
            'recall_train',
            'recall_valid',
            'precision_train',
            'precision_valid',
            'f1_train',
            'f1_valid',
            'auc_roc_valid'
        ]
        # A.3.1. Цикл перебора значений максимальной глубины дерева
        for depth in range(1, depth_treshold):
            # A.3.2. Цикл перебора значений минимального
            # количества выборок в листьях
            for leaf in range(1, depth_treshold):
                # A.3.3. Создание объекта структуры данных
                model = model_name(
                    max_depth=depth,
                    min_samples_leaf=leaf,
                    class_weight=class_weight_income,
                    random_state=777
                )
                # A.3.4. Запуск обучения модели на обучающей выборке
                model.fit(features_train_income, target_train_income)
                # A.3.5. Создание переменной с предсказаниями
                # по обучающей выборке признаков
                predictions_train = model.predict(features_train_income)
                # A.3.6. Создание переменной с предсказаниями
                # по валидационной выборке признаков
                predictions_valid = model.predict(features_valid_income)
                # A.3.7. Создание переменной со значением правильности (accuracy)
                # обученной модели на обучающих целевых признаках
                accuracy_train = accuracy_score(target_train_income, predictions_train)
                # A.3.8. Создание переменной со значением правильности (accuracy)
                # обученной модели на валидационных целевых признаках
                accuracy_valid = accuracy_score(target_valid_income, predictions_valid)
                # A.3.9. Создание переменной со значением полноты (Recall)
                # обученной модели на обучающих целевых признаках
                recall_train = recall_score(target_train_income, predictions_train)
                # A.3.10. Создание переменной со значением полноты (Recall)
                # обученной модели на валидационной выборке признаков
                recall_valid = recall_score(target_valid_income, predictions_valid)
                # A.3.11. Создание переменной со значением точности (Precision)
                # обученной модели на обучающих целевых признаках
                precision_train = precision_score(target_train_income, predictions_train, zero_division=0)
                # A.3.12. Создание переменной со значением тоночти (Precision)
                # обученной модели на валидационной выборке признаков
                precision_valid = precision_score(target_valid_income, predictions_valid, zero_division=0)
                # A.3.13. Создание переменной со значением среднего гармонического (F1)
                # обученной модели на обучающих целевых признаках
                f1_train = f1_score(target_train_income, predictions_train)
                # A.3.14. Создание переменной со значением среднего гармонического (F1)
                # обученной модели на валидационной выборке признаков
                f1_valid = f1_score(target_valid_income, predictions_valid)
                # A.3.15. Вычисление вероятности классов на
                # валидационной выборке
                probabilities_valid = model.predict_proba(features_valid)
                # A.3.16. Вычисление площади под ROC-кривой по
                # вероятности класса '1'
                auc_roc_valid = roc_auc_score(target_valid_income, probabilities_valid[:, 1])
                # A.3.17. Заполнение списка в переменной data_value
                # значениями максимальной глубины дерева, минимального
                # количества выборок в листьях, метрик качества
                data_value.append(
                    [
                        depth,
                        leaf,
                        accuracy_train,
                        accuracy_valid,
                        recall_train,
                        recall_valid,
                        precision_train,
                        precision_valid,
                        f1_train,
                        f1_valid,
                        auc_roc_valid
                    ]
                )
                # A.4.1. Логическое условие сохранения параметров модели
                # с лучшим значением среднего гармонического (F1) на
                # валидационной выборке
                if f1_valid > best_f1:
                    # A.4.2. Сохранение текущего значения среднего гармонического (F1)
                    best_f1 = f1_valid
                    # A.4.3. Формирование параметров для построения PR-кривой
                    precision_pr, recall_pr, threshold_pr = precision_recall_curve(
                        target_valid_income,
                        probabilities_valid[:, 1]
                    )
                    # A.4.4. Формирование параметров для построения ROC-кривой
                    fpr, tpr, threshold_roc = roc_curve(
                        target_valid_income,
                        probabilities_valid[:, 1]
                    )
                    # A.4.5. Сохранение лучшей обученной модели
                    best_model = model
        # A.5.1. Формирование датафрейма с комбинациями максимальной глубины
        # дерева и минимального количества выборок в листьях, полученными
        # значениями метрик качества
        new_data = pd.DataFrame(data=data_value, columns=columns_name)
        # A.5.2. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на обучающей выборке
        df_accuracy_train = new_data.loc[
            new_data['accuracy_train'] == new_data['accuracy_train'].max()
        ].reset_index(drop=True)
        # A.5.3. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на валидационной выборке
        df_accuracy_valid = new_data.loc[
            new_data['accuracy_valid'] == new_data['accuracy_valid'].max()
        ].reset_index(drop=True)
        # A.5.4. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на обучающей выборке
        df_f1_train = new_data.loc[
            new_data['f1_train'] == new_data['f1_train'].max()
        ].reset_index(drop=True)
        # A.5.5. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на валидационной выборке
        df_f1_valid = new_data.loc[
            new_data['f1_valid'] == new_data['f1_valid'].max()
        ].reset_index(drop=True)
        # A.6.1. Вывод на экран лучшего значения правильности
        # и значений параметров обучения модели
        print()
        print(
            'Лучшее значение правильности (accuracy) на обучающей выборке: ', df_accuracy_train['accuracy_train'][0], ' при значениях параметров:', '\n',
            '- максимальная глубина дерева: ', df_accuracy_train['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_accuracy_train['leaf_value'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # A.6.2. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обучения модели
        print(
            'Лучшее значение среднего гармонического (F1) на обучающей выборке: ', df_f1_train['f1_train'][0], ' при значениях параметров:', '\n',
            '- максимальная глубина дерева: ', df_f1_train['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_f1_train['leaf_value'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_train['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        print('-------------------------------------------------------------------------------------------------------------------')
        # A.6.3. Вывод на экран лучшего значения правильности
        # и значений параметров обученной модели
        print(
            'Лучшее значение правильности (accuracy) на валидационной выборке: ', df_accuracy_valid['accuracy_valid'][0], ' при значениях параметров:', '\n',
            '- максимальная глубина дерева: ', df_accuracy_valid['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_accuracy_valid['leaf_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_accuracy_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_accuracy_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_accuracy_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_accuracy_valid['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # A.6.4. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обученной модели
        print(
            'Лучшее значение среднего гармонического (F1) на валидационной выборке: ', df_f1_valid['f1_valid'][0], ' при значениях параметров:', '\n',
            '- максимальная глубина дерева: ', df_f1_valid['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_f1_valid['leaf_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_f1_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_f1_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_f1_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на валидационной выборке: ', df_f1_valid['accuracy_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_valid['accuracy_train'][0],
            sep=''
        )
        print()
        # A.7. Вывод сформированного датафрейма new_data на экран
        print()
        print('Датафрейм со значениями параметров обучения и метриками качества:')
        display(new_data)
        print()
        # A.8. Вывод PR-кривой на экран
        print('Визуализация PR-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(recall_pr, precision_pr, where='post')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая Precision-Recall')
        plt.grid(visible=True)
        plt.show()
        print()
        # A.9. Вывод ROC-кривой на экран
        print('Визуализация ROC-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(fpr, tpr, where='post')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая ошибок ROC')
        plt.grid(visible=True)
        plt.show()
        print()
        # A.10. Вывод модели решающего дерева на экран
        print('Визуализация модели решающего дерева:')
        plt.figure(figsize=(100, 100))
        tree.plot_tree(best_model)
        plt.show()
        # A.11. Возвращение функции
        return best_model
# --------------------------------------------------------------------------------------------------------
    # B.2.1. Логическое условие для отбора и обучения
    # модели случайного леса
    if model_name == RandomForestClassifier:
        # B.2.2 Создание переменной, содержащей список списков для
        # заполнения значениями количества деревьев в лесу, 
        # максимальной глубины дерева, минимального количества
        # выборок в листьях, метрик качества из списка
        data_value = []
        # B.2.3. Создание переменной со списком названий колонок
        columns_name = [
            'number_tree',
            'depth_value',
            'leaf_value',
            'accuracy_train',
            'accuracy_valid',
            'recall_train',
            'recall_valid',
            'precision_train',
            'precision_valid',
            'f1_train',
            'f1_valid',
            'auc_roc_valid'
        ]
        # B.3.1. Цикл перебора значений максимальной глубины дерева
        for estim in range(1, estimators_treshold, estimators_step):
            # B.3.2. Цикл перебора значений максимальной глубины дерева
            for depth in range(1, depth_treshold):
                # B.3.3. Цикл перебора значений минимального
                # количества выборок в листьях
                for leaf in range(1, depth_treshold):
                    # B.3.4. Создание объекта структуры данных
                    model = model_name(
                        n_estimators=estim,
                        max_depth=depth,
                        min_samples_leaf=leaf,
                        class_weight=class_weight_income,
                        random_state=777
                    )
                    # B.3.5. Запуск обучения модели на обучающей выборке
                    model.fit(features_train_income, target_train_income)
                    # B.3.6. Создание переменной с предсказаниями
                    # по обучающей выборке признаков
                    predictions_train = model.predict(features_train_income)
                    # B.3.7. Создание переменной с предсказаниями
                    # по валидационной выборке признаков
                    predictions_valid = model.predict(features_valid_income)
                    # B.3.8. Создание переменной со значением правильности (accuracy)
                    # обученной модели на обучающих целевых признаках
                    accuracy_train = accuracy_score(target_train_income, predictions_train)
                    # B.3.9. Создание переменной со значением правильности (accuracy)
                    # обученной модели на валидационных целевых признаках
                    accuracy_valid = accuracy_score(target_valid_income, predictions_valid)
                    # B.3.10. Создание переменной со значением полноты (Recall)
                    # обученной модели на обучающих целевых признаках
                    recall_train = recall_score(target_train_income, predictions_train)
                    # B.3.11. Создание переменной со значением полноты (Recall)
                    # обученной модели на валидационной выборке признаков
                    recall_valid = recall_score(target_valid_income, predictions_valid)
                    # B.3.12. Создание переменной со значением точности (Precision)
                    # обученной модели на обучающих целевых признаках
                    precision_train = precision_score(target_train_income, predictions_train, zero_division=0)
                    # B.3.13. Создание переменной со значением тоночти (Precision)
                    # обученной модели на валидационной выборке признаков
                    precision_valid = precision_score(target_valid_income, predictions_valid, zero_division=0)
                    # B.3.14. Создание переменной со значением среднего гармонического (F1)
                    # обученной модели на обучающих целевых признаках
                    f1_train = f1_score(target_train_income, predictions_train)
                    # B.3.15. Создание переменной со значением среднего гармонического (F1)
                    # обученной модели на валидационной выборке признаков
                    f1_valid = f1_score(target_valid_income, predictions_valid)
                    # B.3.16. Вычисление вероятности классов на
                    # валидационной выборке
                    probabilities_valid = model.predict_proba(features_valid)
                    # B.3.17. Вычисление площади под ROC-кривой по
                    # вероятности класса '1'
                    auc_roc_valid = roc_auc_score(target_valid_income, probabilities_valid[:, 1])
                    # B.3.18. Заполнение списка в переменной data_value
                    # значениями количества деревьев в лесу, максимальной
                    # глубины дерева, минимального количества выборок в
                    # листьях, метрик качества
                    data_value.append(
                        [
                            estim,
                            depth,
                            leaf,
                            accuracy_train,
                            accuracy_valid,
                            recall_train,
                            recall_valid,
                            precision_train,
                            precision_valid,
                            f1_train,
                            f1_valid,
                            auc_roc_valid
                        ]
                    )
                    # B.4.1. Логическое условие сохранения параметров модели
                    # с лучшим значением среднего гармонического (F1) на
                    # валидационной выборке
                    if f1_valid > best_f1:
                        # B.4.2. Сохранение текущего значения среднего гармонического (F1)
                        best_f1 = f1_valid
                        # B.4.3. Формирование параметров для построения PR-кривой
                        precision_pr, recall_pr, threshold_pr = precision_recall_curve(
                            target_valid_income,
                            probabilities_valid[:, 1]
                        )
                        # B.4.4. Формирование параметров для построения ROC-кривой
                        fpr, tpr, threshold_roc = roc_curve(
                            target_valid_income,
                            probabilities_valid[:, 1]
                        )
                        # B.4.5. Сохранение лучшей обученной модели
                        best_model = model
        # B.5.1. Формирование датафрейма с комбинациями количества деревьев в лесу,
        # максимальной глубины дерева и минимального количества выборок в листьях,
        # полученными значениями метрик качества
        new_data = pd.DataFrame(data=data_value, columns=columns_name)
        # B.5.2. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на обучающей выборке
        df_accuracy_train = new_data.loc[
            new_data['accuracy_train'] == new_data['accuracy_train'].max()
        ].reset_index(drop=True)
        # B.5.3. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на валидационной выборке
        df_accuracy_valid = new_data.loc[
            new_data['accuracy_valid'] == new_data['accuracy_valid'].max()
        ].reset_index(drop=True)
        # B.5.4. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на обучающей выборке
        df_f1_train = new_data.loc[
            new_data['f1_train'] == new_data['f1_train'].max()
        ].reset_index(drop=True)
        # B.5.5. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на валидационной выборке
        df_f1_valid = new_data.loc[
            new_data['f1_valid'] == new_data['f1_valid'].max()
        ].reset_index(drop=True)
        # B.6.1. Вывод на экран лучшего значения правильности
        # и значений параметров обучения модели
        print()
        print(
            'Лучшее значение правильности (accuracy) на обучающей выборке: ', df_accuracy_train['accuracy_train'][0], ' при значениях параметров:', '\n',
            '- количество деревьев в лесу: ', df_accuracy_train['number_tree'][0], '\n',
            '- максимальная глубина дерева: ', df_accuracy_train['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_accuracy_train['leaf_value'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # B.6.2. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обучения модели
        print(
            'Лучшее значение среднего гармонического (F1) на обучающей выборке: ', df_f1_train['f1_train'][0], ' при значениях параметров:', '\n',
            '- количество деревьев в лесу: ', df_f1_train['number_tree'][0], '\n',
            '- максимальная глубина дерева: ', df_f1_train['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_f1_train['leaf_value'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_train['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        print('-------------------------------------------------------------------------------------------------------------------')
        # B.6.3. Вывод на экран лучшего значения правильности
        # и значений параметров обученной модели
        print(
            'Лучшее значение правильности (accuracy) на валидационной выборке: ', df_accuracy_valid['accuracy_valid'][0], ' при значениях параметров:', '\n',
            '- количество деревьев в лесу: ', df_accuracy_valid['number_tree'][0], '\n',
            '- максимальная глубина дерева: ', df_accuracy_valid['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_accuracy_valid['leaf_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_accuracy_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_accuracy_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_accuracy_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_accuracy_valid['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # B.6.4. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обученной модели
        print(
            'Лучшее значение среднего гармонического (F1) на валидационной выборке: ', df_f1_valid['f1_valid'][0], ' при значениях параметров:', '\n',
            '- количество деревьев в лесу: ', df_f1_valid['number_tree'][0], '\n',
            '- максимальная глубина дерева: ', df_f1_valid['depth_value'][0], '\n',
            '- минимальное количество выборок в листе: ', df_f1_valid['leaf_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_f1_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_f1_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_f1_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на валидационной выборке: ', df_f1_valid['accuracy_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_valid['accuracy_train'][0],
            sep=''
        )
        print()
        # B.7. Вывод сформированного датафрейма new_data на экран
        print()
        print('Датафрейм со значениями параметров обучения и метриками качества:')
        display(new_data)
        print()
        # B.8. Вывод PR-кривой на экран
        print('Визуализация PR-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(recall_pr, precision_pr, where='post')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая Precision-Recall')
        plt.grid(visible=True)
        plt.show()
        print()
        # B.9. Вывод ROC-кривой на экран
        print('Визуализация ROC-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(fpr, tpr, where='post')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая ошибок ROC')
        plt.grid(visible=True)
        plt.show()
        # B.10. Возвращение функции
        return best_model
# --------------------------------------------------------------------------------------------------------
    # C.2.1. Логическое условие для отбора и обучения
    # модели логистической ргрессии
    if model_name == LogisticRegression:
        # С.2.2 Создание переменной, содержащей список списков для
        # заполнения значениями максимального количества итераций,
        # метрик качества из списка
        data_value = []
        # С.2.3. Создание переменной со списком названий колонок
        columns_name = [
            'iter_value',
            'accuracy_train',
            'accuracy_valid',
            'recall_train',
            'recall_valid',
            'precision_train',
            'precision_valid',
            'f1_train',
            'f1_valid',
            'auc_roc_valid'
        ]
        # С.3.1. Цикл перебора значений количества итераций
        for num_iter in range(iter_start, iter_treshold):
            # C.3.2. Создание объекта структуры данных
            model = model_name(
                solver=solver_used,
                max_iter=num_iter,
                class_weight=class_weight_income,
                random_state=777
            )
            # C.3.3. Запуск обучения модели на обучающей выборке
            model.fit(features_train_income, target_train_income)
            # C.3.4. Создание переменной с предсказаниями
            # по обучающей выборке признаков
            predictions_train = model.predict(features_train_income)
            # C.3.5. Создание переменной с предсказаниями
            # по валидационной выборке признаков
            predictions_valid = model.predict(features_valid_income)
            # C.3.6. Создание переменной со значением правильности (accuracy)
            # обученной модели на обучающих целевых признаках
            accuracy_train = accuracy_score(target_train_income, predictions_train)
            # C.3.7. Создание переменной со значением правильности (accuracy)
            # обученной модели на валидационных целевых признаках
            accuracy_valid = accuracy_score(target_valid_income, predictions_valid)
            # C.3.8. Создание переменной со значением полноты (Recall)
            # обученной модели на обучающих целевых признаках
            recall_train = recall_score(target_train_income, predictions_train)
            # C.3.9. Создание переменной со значением полноты (Recall)
            # обученной модели на валидационной выборке признаков
            recall_valid = recall_score(target_valid_income, predictions_valid)
            # C.3.10. Создание переменной со значением точности (Precision)
            # обученной модели на обучающих целевых признаках
            precision_train = precision_score(target_train_income, predictions_train, zero_division=0)
            # C.3.11. Создание переменной со значением тоночти (Precision)
            # обученной модели на валидационной выборке признаков
            precision_valid = precision_score(target_valid_income, predictions_valid, zero_division=0)
            # C.3.12. Создание переменной со значением среднего гармонического (F1)
            # обученной модели на обучающих целевых признаках
            f1_train = f1_score(target_train_income, predictions_train)
            # C.3.13. Создание переменной со значением среднего гармонического (F1)
            # обученной модели на валидационной выборке признаков
            f1_valid = f1_score(target_valid_income, predictions_valid)
            # C.3.14. Вычисление вероятности классов на
            # валидационной выборке
            probabilities_valid = model.predict_proba(features_valid)
            # C.3.15. Вычисление площади под ROC-кривой по
            # вероятности класса '1'
            auc_roc_valid = roc_auc_score(target_valid_income, probabilities_valid[:, 1])
            # C.3.16. Заполнение списка в переменной data_value
            # значениями количества итераций и метрик качества
            data_value.append(
                [
                    num_iter,
                    accuracy_train,
                    accuracy_valid,
                    recall_train,
                    recall_valid,
                    precision_train,
                    precision_valid,
                    f1_train,
                    f1_valid,
                    auc_roc_valid
                ]
            )
            # C.4.1. Логическое условие сохранения параметров модели
            # с лучшим значением среднего гармонического (F1) на
            # валидационной выборке
            if f1_valid > best_f1:
                # C.4.2. Сохранение текущего значения среднего гармонического (F1)
                best_f1 = f1_valid
                # C.4.3. Формирование параметров для построения PR-кривой
                precision_pr, recall_pr, threshold_pr = precision_recall_curve(
                    target_valid_income,
                    probabilities_valid[:, 1]
                )
                # C.4.4. Формирование параметров для построения ROC-кривой
                fpr, tpr, threshold_roc = roc_curve(
                    target_valid_income,
                    probabilities_valid[:, 1]
                )
                # C.4.5. Сохранение лучшей обученной модели
                best_model = model
        # C.5.1. Формирование датафрейма с комбинациями количества итераций
        # и полученными значениями правильности (accuracy)
        new_data = pd.DataFrame(data=data_value, columns=columns_name)
        # C.5.2. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на обучающей выборке
        df_accuracy_train = new_data.loc[
            new_data['accuracy_train'] == new_data['accuracy_train'].max()
        ].reset_index(drop=True)
        # C.5.3. Формирование датафрейма с количеством итераций для лучшего
        # значения правильности (accuracy) на валидационной выборке
        df_accuracy_valid = new_data.loc[
            new_data['accuracy_valid'] == new_data['accuracy_valid'].max()
        ].reset_index(drop=True)
        # C.5.4. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на обучающей выборке
        df_f1_train = new_data.loc[
            new_data['f1_train'] == new_data['f1_train'].max()
        ].reset_index(drop=True)
        # C.5.5. Формирование датафрейма с количеством итераций для лучшего
        # значения среднего гармонического (F1) на валидационной выборке
        df_f1_valid = new_data.loc[
            new_data['f1_valid'] == new_data['f1_valid'].max()
        ].reset_index(drop=True)
        # С.6.1. Вывод на экран лучшего значения правильности
        # и значений параметров обучения модели
        print()
        print(
            'Лучшее значение правильности (accuracy) на обучающей выборке: ', df_accuracy_train['accuracy_train'][0], ' при значениях параметров:', '\n',
            '- максимальное количество итераций: ', df_accuracy_train['iter_value'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # C.6.2. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обучения модели
        print(
            'Лучшее значение среднего гармонического (F1) на обучающей выборке: ', df_f1_train['f1_train'][0], ' при значениях параметров:', '\n',
            '- максимальное количество итераций: ', df_f1_train['iter_value'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_train['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        print('-------------------------------------------------------------------------------------------------------------------')
        # C.6.3. Вывод на экран лучшего значения правильности
        # и значений параметров обученной модели
        print(
            'Лучшее значение правильности (accuracy) на валидационной выборке: ', df_accuracy_valid['accuracy_valid'][0], ' при значениях параметров:', '\n',
            '- максимальное количество итераций: ', df_accuracy_valid['iter_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_accuracy_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_accuracy_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_accuracy_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_accuracy_valid['accuracy_train'][0],
            sep=''
        )
        print('-------------------------------------------------------------------------------------------------------------------')
        # C.6.4. Вывод на экран лучшего значения среднего гармонического
        # и значений параметров обученной модели
        print(
            'Лучшее значение среднего гармонического (F1) на валидационной выборке: ', df_f1_valid['f1_valid'][0], ' при значениях параметров:', '\n',
            '- максимальное количество итераций: ', df_f1_valid['iter_value'][0], '\n',
            '- текущее значение полноты (Recall) на валидационной выборке: ', df_f1_valid['recall_valid'][0], '\n',
            '- текущее значение точности (Precision) на валидационной выборке: ', df_f1_valid['precision_valid'][0], '\n',
            '- текущее значение площади AUC-ROC под ROC-кривой на валидационной выборке: ', df_f1_valid['auc_roc_valid'][0], '\n',
            '- текущая правильность (accuracy) на валидационной выборке: ', df_f1_valid['accuracy_valid'][0], '\n',
            '- текущая правильность (accuracy) на обучающей выборке: ', df_f1_valid['accuracy_train'][0],
            sep=''
        )
        print()
        # C.7. Вывод сформированного датафрейма new_data на экран
        display(new_data)
        print()
        # C.8. Вывод PR-кривой на экран
        print('Визуализация PR-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(recall_pr, precision_pr, where='post')
        plt.xlabel('Recall')
        plt.ylabel('Precision')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая Precision-Recall')
        plt.grid(visible=True)
        plt.show()
        print()
        # C.9. Вывод ROC-кривой на экран
        print('Визуализация ROC-кривой:')
        plt.figure(figsize=(6, 6))
        plt.step(fpr, tpr, where='post')
        plt.xlabel('False Positive Rate')
        plt.ylabel('True Positive Rate')
        plt.ylim([0.0, 1.05])
        plt.xlim([0.0, 1.05])
        plt.title('Кривая ошибок ROC')
        plt.grid(visible=True)
        plt.show()
        # C.10. Возвращение функции
        return best_model

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Успех:</b> На все случаи жизни ) Отлично, что активно пользуешься функциями 👍
# </div>

# %% [markdown]
# #### Исследование модели решающего дерева - DecisionTreeClassifier

# %%
# %%time
# Формирование и обучение модели решающего дерева
# с выводом времени обучения
model_tree = model_select(
    DecisionTreeClassifier,
    features_train,
    target_train,
    features_valid,
    target_valid,
    26
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 24
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 24
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 1.0
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.869 при значениях параметров:
# - максимальная глубина дерева: 6
# - минимальное количество выборок в листе: 4
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.2.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Чем глубже решающее дерево, тем дольше оно обучается.\
#     2. Оптимально решающее дерево обучается до глубины дерева 6 и количества выборок в листе 4.\
#     Значение правильности (accuracy) при этих параметрах на валидационной выборке составляет 0.869, а текущая правильность (accuracy) на обучающей выборке 0.8691666666666666.\
#     При этом полнота (Recall - доля истинно-положительных ответов) на валидационной выборке 0.4410958904109589, точность (Precision - доля истинно-положительных ответов с учётом ошибочных) 0.7351598173515982.\
#     Площадь AUC-ROC под ROC-кривой 0.8364157345733315 значительно больше, чем у случайной модели 0.5.\
#     3. Лучшее значение среднего гармонического (F1) равняется 0.5675675675675675 и достигается при глубине дерева 7 и количестве выборок в листе 3.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке выросла до 0.5178082191780822, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) понизилась до 0.627906976744186.\
#     Площадь AUC-ROC под ROC-кривой составляет 0.8273109630932931, что всё так же значительно больше, чем у случайной модели 0.5.\
#     Модель немного переобучается, и показывает текущие правильности (accuracy) на валидационной выборке 0.856 и на обучающей выборке 0.8765.\
#     4. Затем дерево начинает переобучаться до глубины дерева 24 и количества выборок в листе 1 со значениями правильности (accuracy) и среднего гармонического (F1) на обучающей выборке, равным 1.0.</b></span></div>

# %% [markdown]
# #### Исследование модели случайного леса - RandomForestClassifier

# %%
# %%time
# Формирование и обучение модели случайного леса
# с выводом времени обучения
model_random_forest = model_select(
    RandomForestClassifier,
    features_train,
    target_train,
    features_valid,
    target_valid,
    23,
    11,
    1
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.9895 при значениях параметров:
# - количество деревьев в лесу: 9
# - максимальная глубина дерева: 22
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.9736732135394901 при значениях параметров:
# - количество деревьев в лесу: 9
# - максимальная глубина дерева: 22
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 0.9895
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.875 при значениях параметров:
# - количество деревьев в лесу: 10
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.2.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Чем больше деревьев и чем глубже деревья, тем дольше случайный лес обучается.\
#     2. Оптимально случайный лес обучается до 10 деревьев глубиной дерева 13 с количеством выборок в листе 10.\
#   Значение правильности (accuracy) при этих параметрах на валидационной выборке составляет 0.875, а текущая правильность (accuracy) на обучающей выборке 0.8831666666666667.\
#     При этом полнота (Recall - доля истинно-положительных ответов) на валидационной выборке 0.4794520547945205, точность (Precision - доля истинно-положительных ответов с учётом ошибочных) 0.7446808510638298.\
#     Площадь AUC-ROC под ROC-кривой 0.8493686900423107 значительно больше, чем у случайной модели 0.5.\
#     3. Лучшее значение среднего гармонического (F1) равняется 0.5958132045088567 и достигается при 8 деревьях глубиной дерева 11 и количестве выборок в листе 3.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке выросла до 0.5068493150684932, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) понизилась до 0.72265625.\
#     Площадь AUC-ROC под ROC-кривой составляет 0.8549352771144904, что всё так же значительно больше, чем у случайной модели 0.5.\
#     Модель немного переобучается, и показывает текущие правильности (accuracy) на валидационной выборке 0.8745 и на обучающей выборке 0.9028333333333334.\
#     4. Затем случайный лес начинает переобучаться до 9 деревьем глубиной дерева 22 с количеством выборок в листе 1 со значениями правильности (accuracy) 0.9895 и среднего гармонического (F1) 0.9736732135394901 на обучающей выборке.\
#     5. Если увеличить число деревьев, то прирост метрик качества будет незначительным, а время обучения модели увеличится в разы.</b></span></div>

# %% [markdown]
# #### Исследование модели логистической регрессии - LogisticRegression

# %%
# Отключение предупреждения ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
# Increase the number of iterations (max_iter) or scale the data
# warnings.filterwarnings(action='ignore', message='lbfgs failed to converge')

# %%
# %%time
# Формирование и обучение модели логистической регрессии
# с решателем solver='lbfgs' с выводом времени обучения
model_logistic1 = model_select(
    LogisticRegression,
    features_train,
    target_train,
    features_valid,
    target_valid,
    iter_start=1,
    iter_treshold=100
)
# Out:
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /opt/conda/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.2.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Модель обучается не очень быстро, а также почти не переобучается.\
#     2. Для значений количества итераций от 1 до 21 появляется предупреждение о недостаточном количестве итераций для схождения.\
#     Необходимо увеличить минимальное количество итераций до 22 и более для избежания появления предупреждения.\
#     3. Модель логистической регрессии обучается до количества итераций, равного 8.\
#     Значение правильности (accuracy) при этих параметрах на валидационной выборке составляет 0.8295, а текущая правильность (accuracy) на обучающей выборке 0.8131666666666667.\
#     При этом полнота (Recall - доля истинно-положительных ответов) на валидационной выборке 0.22465753424657534, точность (Precision - доля истинно-положительных ответов с учётом ошибочных) 0.5857142857142857.\
#     Площадь AUC-ROC под ROC-кривой 0.758518704704453 значительно больше, чем у случайной модели 0.5.\
#     4. Лучшее значение среднего гармонического (F1) равняется 0.32677165354330706 и достигается при 9 итерациях.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке выросла до 0.2273972602739726, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) понизилась до 0.5804195804195804.\
#     Площадь AUC-ROC под ROC-кривой составляет 0.7585237317246868, что всё так же значительно больше, чем у случайной модели 0.5.\
#     Модель немного переобучается, и показывает текущие правильности (accuracy) на валидационной выборке 0.829 и на обучающей выборке 0.8138333333333333.\
#     5. Затем начинается незначительное переобучение до количества итераций, равного 9, со значениями правильности (accuracy) 0.8138333333333333 и среднего гармонического (F1) 0.32993401319736054 на обучающей выборке.\
#     6. После количества итераций, равного 20, значения метрик качества на выборках перестают расти.</b></span></div>

# %%
# %%time
# Формирование и обучение модели логистической регрессии
# с решателем solver='lbfgs' с выводом времени обучения
model_logistic2 = model_select(
    LogisticRegression,
    features_train,
    target_train,
    features_valid,
    target_valid,
    iter_start=22,
    iter_treshold=100
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.8126666666666666 при значениях параметров:
# - максимальное количество итераций: 22
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.32289156626506027 при значениях параметров:
# - максимальное количество итераций: 22
# - текущая правильность (accuracy) на обучающей выборке: 0.8126666666666666
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.8285 при значениях параметров:
# - максимальное количество итераций: 22
# - текущее значение полноты (Recall) на валидационной выборке: 0.21643835616438356
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.2.4:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Предупреждение о недостаточном количестве итераций для схождения не появляется.\
#     2. При количестве итераций, равном 22, значение среднего гармонического (F1) равняется 0.3153692614770459.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке понизилась до 0.21643835616438356, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) выросла до 0.5808823529411765.\
#     Площадь AUC-ROC под ROC-кривой составляет 0.7612651334254954, что всё так же больше, чем у случайной модели 0.5.\
#     Текущие правильности (accuracy) на валидационной выборке 0.8285 и на обучающей выборке 0.8126666666666666.</b></span></div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Созданная функция 'model_select()' работает, успешно обучает и формирует любую из трёх моделей ML (DecisionTreeClassifier, RandomForestClassifier, LogistisRegression), выводит значения параметров обучения, при которых модель переобучается, лучшие значения параметров на валидационных выборках, а также метрики качества.\
#     2.1. Из трёх моделей лучшие значения метрик качества на валидационной выборке имеет случайный лес (RandomForestClassifier) при 10 деревьях глубиной дерева 13 с количеством выборок в листе 10.\
#     Значение правильности (accuracy) при этих параметрах на валидационной выборке составляет 0.875, а текущая правильность (accuracy) на обучающей выборке 0.8831666666666667.\
#     При этом полнота (Recall - доля истинно-положительных ответов) на валидационной выборке 0.4794520547945205, точность (Precision - доля истинно-положительных ответов с учётом ошибочных) 0.7446808510638298.\
#     Площадь AUC-ROC под ROC-кривой 0.8493686900423107 значительно больше, чем у случайной модели 0.5.\
#     2.2. Лучшее значение среднего гармонического (F1) равняется 0.5958132045088567 и достигается при 8 деревьях глубиной дерева 11 и количестве выборок в листе 3.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке выросла до 0.5068493150684932, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) понизилась до 0.72265625.\
#     Площадь AUC-ROC под ROC-кривой составляет 0.8549352771144904, что больше, чем у моделей DecisionTreeClassifier и LogistisRegression.\
#     Модель немного переобучается, и показывает текущие правильности (accuracy) на валидационной выборке 0.8745 и на обучающей выборке 0.9028333333333334.\
#     3. На втором месте решающее дерево (DecisionTreeClassifier).\
#     4. На третьем месте модель логистической регрессии (LogistisRegression).</b></span></div>

# %% [markdown]
# ### Проверка моделей на тестовой выборке

# %% [markdown]
# #### Проверка модели решающего дерева - DecisionTreeClassifier

# %%
# Формирование переменной с предсказаниями по тестовой
# выборке признаков (вопросов) моделью model_tree
predictions_test_tree1 = model_tree.predict(features_test)

# %%
# Вывод отчёта по метрикам качества модели model_tree
print(classification_report(target_test, predictions_test_tree1, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.87      0.93      0.90      1543
#      class 1       0.70      0.52      0.59       457
#
#     accuracy                           0.84      2000
#    macro avg       0.78      0.72      0.75      2000
# weighted avg       0.83      0.84      0.83      2000

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.3.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Значение среднего гармонического (F1) на тестовой выборке составляет 0.59 и немного выше значения на валидационной выборке - 0.57.</b></span></div>

# %% [markdown]
# #### Проверка модели случайного леса - RandomForestClassifier

# %%
# Формирование переменной с предсказаниями по тестовой
# выборке признаков (вопросов) моделью model_random_forest
predictions_test_forest1 = model_random_forest.predict(features_test)

# %%
# Вывод отчёта по метрикам качества модели model_random_forest
print(classification_report(target_test, predictions_test_forest1, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.87      0.95      0.91      1543
#      class 1       0.75      0.50      0.60       457
#
#     accuracy                           0.85      2000
#    macro avg       0.81      0.73      0.75      2000
# weighted avg       0.84      0.85      0.84      2000

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.3.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Значение среднего гармонического (F1) на тестовой выборке составляет 0.60 и немного выше значения на валидационной выборке - 0.59.</b></span></div>

# %% [markdown]
# #### Проверка модели логистической регрессии - LogisticRegression

# %%
# Формирование переменной с предсказаниями по тестовой
# выборке признаков (вопросов) моделью model_logistic2
predictions_test_logistic1 = model_logistic2.predict(features_test)

# %%
# Вывод отчёта по метрикам качества модели model_logistic2
print(classification_report(target_test, predictions_test_logistic1, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.80      0.96      0.88      1543
#      class 1       0.62      0.21      0.31       457
#
#     accuracy                           0.79      2000
#    macro avg       0.71      0.58      0.59      2000
# weighted avg       0.76      0.79      0.75      2000

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.3.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Значение среднего гармонического (F1) на тестовой выборке составляет 0.31 и немного ниже значения на валидационной выборке - 0.32.</b></span></div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Из трёх моделей лучшее значение среднего гармонического (F1) на тестовой выборке имеет случайный лес (RandomForestClassifier) - 0.60.\
#     2. На втором месте решающее дерево (DecisionTreeClassifier) со значением среднего гармонического (F1) на тестовой выборке 0.59.\
#     3. На третьем месте модель логистической регрессии (LogistisRegression). Значение среднего гармонического (F1) на тестовой выборке 0.31.</b></span></div>

# %% [markdown]
# ### Проверка модели на адекватность

# %% [markdown]
# **На адекватность проверю модель с лучшим значением F1 - model_random_forest**

# %% [markdown]
# #### Проверка модели model_random_forest

# %%
# Формирование матрицы ошибок cm_forest1
cm_forest1 = confusion_matrix(
    y_true=target_test,
    y_pred=predictions_test_forest1,
    labels=model_random_forest.classes_,
    normalize='true'
)

# %%
# Вывод на экран матрицы ошибок cm_forest1
ConfusionMatrixDisplay(
    confusion_matrix=cm_forest1,
    display_labels=model_random_forest.classes_
).plot()
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.4.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 95% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 50%.\
#     2. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 50% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 5%.\
#     3. Составлю базовую модель с фиктивными классификаторами (DummyClassifier()), которая делает прогнозы, не пытаясь найти закономерности в данных. Модель по умолчанию по существу рассматривает, какая метка наиболее часто встречается в обучающем наборе данных, и делает прогнозы на основе этой метки.</b></span></div>

# %% [markdown]
# #### Создание и проверка модели DummyClassifier

# %%
# Формирование структуры данных фиктивного
# классификатора DummyClassifier
model_dummy1 = DummyClassifier(strategy='stratified', random_state=777)

# %%
# Запуск обучения модели на обучающей выборке
model_dummy1.fit(features_train, target_train)
# Out:
# DummyClassifier(random_state=777, strategy='stratified')

# %%
# Создание переменной с предсказаниями по тестовой
# выборке признаков (вопросов) моделью model_dummy1
predictions_test_dummy1 = model_dummy1.predict(features_test)

# %%
# Формирование матрицы ошибок cm_dummy1
cm_dummy1 = confusion_matrix(
    target_test,
    predictions_test_dummy1,
    labels=model_dummy1.classes_,
    normalize='true'
)

# %%
# Вывод на экран матрицы ошибок cm_dummy1
ConfusionMatrixDisplay(
    confusion_matrix=cm_dummy1,
    display_labels=model_dummy1.classes_
).plot()
plt.show()

# %%
# Вывод на экран уникальных значений и их
# количества в target_train в пропорциях
target_train.value_counts(normalize=True)
# Out:
# 0    0.7975
# 1    0.2025
# Name: exited, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.4.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Дисбаланс классов - в обучающем наборе данных features_train гораздо больше клиентов (80%), являющихся пользователями услуг банка, чем тех, кто расторгнул договор (20%), поэтому фиктивный классификатор предсказывает лучше текущих клиентов банка.\
# В связи с этим model_random_forest хорошо определяет клиентов, являющихся пользователями услуг банка, а хуже - расторгнувших договор.\
#     2. Для удаления дисбаланса выполняю передискретизацию. С помощью SMOTENC создаю синтетические выборки, похожие на реальные данные, чтобы уравнять классы.</b></span></div>

# %% [markdown]
# #### Создание синтетических обучающих выборок SMOTENC

# %%
# Создание объекта структуры данных SMOTENC
# sm = SMOTENC(categorical_features=[0, 1], random_state=777)

# %%
# Формирование синтетических выборок с признаками features_train_sm
# и целевыми признаками target_train_sm
# features_train_sm, target_train_sm = sm.fit_resample(features_train, target_train)

# %%
# Вывод на экран уникальных значений и их
# количества в target_train_sm в пропорциях
# target_train_sm.value_counts(normalize=True)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.4.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Синтетические выборки созданы. Дисбаланс классов устранён.\
#     2. Необходимо обучить обе модели на синтетических выборках и сравнить матрицы ошибок.</b></span></div>

# %% [markdown]
# #### Создание и проверка модели model_random_forest_sm

# %%
# Формирование и обучение модели случайного леса
# на синтетических выборках
# model_random_forest_sm = model_select(
#    RandomForestClassifier,
#    features_train_sm,
#    target_train_sm,
#    features_valid,
#    target_valid,
#    23,
#    11,
#    1
# )

# %%
# Создание переменной с предсказаниями по тестовой
# выборке признаков обученной моделью model_random_forest_sm
# predictions_test_forest_sm = model_random_forest_sm.predict(features_test)

# %%
# Формирование матрицы ошибок cm_forest_sm
# cm_forest_sm = confusion_matrix(
#    y_true=target_test,
#    y_pred=predictions_test_forest_sm,
#    labels=model_random_forest_sm.classes_,
#    normalize='true'
# )

# %%
# Вывод на экран матрицы ошибок cm_forest_sm
# ConfusionMatrixDisplay(
#    confusion_matrix=cm_forest_sm,
#    display_labels=model_random_forest_sm.classes_
# ).plot()
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.4.4:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 84% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 69%.\
#     2. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 31% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 16%.</b></span></div>

# %% [markdown]
# #### Создание и проверка модели model_dummy_sm

# %%
# Создание объекта структуры данных фиктивного
# классификатора DummyClassifier
# model_dummy_sm = DummyClassifier(strategy='stratified', random_state=777)

# %%
# Запуск обучения модели на обучающей выборке
# model_dummy_sm.fit(features_train_sm, target_train_sm)

# %%
# Создание переменной с предсказаниями по тестовой
# выборке признаков обученной моделью model_dummy_sm
# predictions_test_dummy_sm = model_dummy_sm.predict(features_test)

# %%
# Формирование матрицы ошибок cm_dummy_sm
# cm_dummy_sm = confusion_matrix(
#    y_true=target_test,
#    y_pred=predictions_test_dummy_sm,
#    labels=model_dummy_sm.classes_,
#    normalize='true'
# )

# %%
# Вывод на экран матрицы ошибок cm_dummy_sm
# ConfusionMatrixDisplay(
#    confusion_matrix=cm_dummy_sm,
#    display_labels=model_dummy_sm.classes_
# ).plot()
# plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 3.4.5:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 50% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 49%.\
#     2. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 51% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 50%.</b></span></div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 95% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 50%.\
#     2. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 50% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 5%.\
#     3. После составления базовой модели с фиктивными классификаторами (DummyClassifier), которая делает прогнозы, не пытаясь найти закономерности в данных, был выявлен дисбаланс классов, связанный с тем, что в наборе данных обучающей базы гораздо больше клиентов (80%), являющихся пользователями услуг банка, чем тех, кто расторгнул договор (20%), поэтому фиктивный классификатор предсказывает лучше текущих клиентов банка.\
# Из этого следует, что model_random_forest хорошо определяет клиентов, являющихся пользователями услуг банка, а хуже - расторгнувших договор.\
#     4. После создания с помощью SMOTENC синтетическихх выборок, похожих на реальные данные, был устранён дисбаланс классов в данных.\
#     5. Повторное обучение обеих моделей на синтетических выборках и дальнейшее сравнение матриц ошибок показало, что модель model_random_forest_sm фактически увеличила свои показатели по количеству верных ответов на 19% (с 50% до 69%), превысив показатель базовой модели model_dummy_sm с фиктивными классификаторами на 20%.\
#     6. Исходя из выполненной проверки модели на адекватность, делаю вывод, что у обученной модели обученной модели model_random_forest необходимо улучшать метрики качества Recall (полнота), Precision (точность) и F1 (среднее гармоническое). Для текущей бизнес-задачи она мало подходит.\
#     Для улучшения показателей метрик качества необходимо устранить дисбаланс классов, увеличивая в обучающей выборке долю данных, относящихся к целевому классу 1.0 - клиенты, расторгнувшие договор; либо уменьшая в обучающей выборке долю данных, относящихся к целевому классу 0.0 - клиенты, являющиеся пользователями услуг банка.</b></span></div>

# %% [markdown]
# ## Борьба с дисбалансом классов

# %% [markdown]
# ### Исследование параметра class_weight

# %%
# %%time
# Формирование и обучение модели случайного леса
# с выводом времени обучения
model_random_forest = model_select(
    RandomForestClassifier,
    features_train,
    target_train,
    features_valid,
    target_valid,
    23,
    11,
    1,
    class_weight_income='balanced'
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.9891666666666666 при значениях параметров:
# - количество деревьев в лесу: 9
# - максимальная глубина дерева: 21
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.9728147218736929 при значениях параметров:
# - количество деревьев в лесу: 9
# - максимальная глубина дерева: 21
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 0.9891666666666666
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.865 при значениях параметров:
# ...

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>После задания параметру 'class_weight' значения 'balanced' среднее гармоническое (F1) составило 0.5944517833553501, что незначительно ниже, чем с несбалансированным вариантом.\
#     Площадь (AUC-ROC) под кривой ROC понизилась до 0.8393699467973692.\
#     При этом значение полноты (Recall) увеличилось до 0.6164383561643836, а точность (Precision) понизилась до 0.5739795918367347.\
#     Модель немного переобучилась.</b></span></div>

# %% [markdown]
# ### Разделение признаков обучающих выборок по классам

# %%
# Разделение признаков (вопросов) и целевых признаков (ответов)
# в обучающих выборках по классам (0 и 1)
features_train_0 = features_train[target_train == 0]
features_train_1 = features_train[target_train == 1]
target_train_0 = target_train[target_train == 0]
target_train_1 = target_train[target_train == 1]

# %%
# Вывод уникальных значений в target_train
# по долям в процентах
target_train.value_counts(normalize=True)
# Out:
# 0    0.7975
# 1    0.2025
# Name: exited, dtype: float64

# %%
# Создание переменной с частным из отношения количества
# значений класса 0 к количеству значений класса 1 и
# вывод значения на экран
ratio = np.ceil(
    len(target_train[target_train == 0]) / len(target_train[target_train == 1])
).astype('int64')
ratio
# Out:
# 4

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.2.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Разделение обучающих выборок по классам выполнено успешно.\
#     2. Превышение класса '0' над классом '1' примерно в 4 раза.</b></span></div>

# %% [markdown]
# ### Исследование результатов увеличенния обучающих данных

# %% [markdown]
# #### Формирование увеличенных обучающих данных (upsampling)

# %%
# Увеличение выборки признаков, относящихся к классу 1,
# с дальнейшим объединением с выборкой класса 0
features_train_upsampled = pd.concat(
    [features_train_0] + [features_train_1] * 3
)
target_train_upsampled = pd.concat(
    [target_train_0] + [target_train_1] * 3
)

# %%
# Перемешивание данных в обучающих выборках
features_train_upsampled, target_train_upsampled = shuffle(
    features_train_upsampled,
    target_train_upsampled,
    random_state=777
)

# %%
# Вывод уникальных значений в target_train_upsampled
# по долям в процентах
target_train_upsampled.value_counts(normalize=True)
# Out:
# 0    0.567616
# 1    0.432384
# Name: exited, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.3.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Увеличение размера и перемешивание выборок с классом '1' выполняется корректно.</b></span></div>

# %% [markdown]
# #### Исследование модели решающего дерева - DecisionTreeClassifier

# %%
# %%time
# Формирование и обучение модели решающего дерева
# с выводом времени обучения
model_upsampled_tree = model_select(
    DecisionTreeClassifier,
    features_train_upsampled,
    target_train_upsampled,
    features_valid,
    target_valid,
    26
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 24
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 24
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 1.0
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.8505 при значениях параметров:
# - максимальная глубина дерева: 5
# - минимальное количество выборок в листе: 14
# ...

# %%
# Создание списка названий колонок с метриками качества
columns_model = [
    'action',
    'f1_valid',
    'recall_valid',
    'precision_valid',
    'auc_roc_valid',
    'accuracy_valid',
    'accuracy_train'
]

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '1'
action_upsampled_tree = [
    ['увеличение класса "1" в 2 раза', 0.5750000000000001, 0.5671232876712329, 0.5830985915492958, 0.8309454987222991, 0.847, 0.8316008316008316],
    ['увеличение класса "1" в 3 раза', 0.5694603903559128, 0.6794520547945205, 0.4901185770750988, 0.8162188429475097, 0.8125, 0.8302491103202847],
    ['увеличение класса "1" в 4 раза', 0.5465968586387434, 0.7150684931506849, 0.4423728813559322, 0.8128398475137197, 0.7835, 0.8171073094867807]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '1'
df_upsampled_tree = pd.DataFrame(data=action_upsampled_tree, columns=columns_model)
df_upsampled_tree
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  увеличение класса "1" в 2 раза  0.575000      0.567123         0.583099
# 1  увеличение класса "1" в 3 раза  0.569460      0.679452         0.490119
# 2  увеличение класса "1" в 4 раза  0.546597      0.715068         0.442373
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.830945          0.8470        0.831601
# 1       0.816219          0.8125        0.830249
# 2       0.812840          0.7835        0.817107

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.3.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Ни одно действие не привело к достижению размера среднего гармонического (F1) до требуемого 0.59.\
#     2. Наибольшие значения среднего гармонического (F1) 0.575 и площади (AUC-ROC) под кривой ROC 0.830945 наблюдаются при увеличении обучающих выборок в 2 раза.\
#     При этом значение полноты (Recall) 0.567123 наименьшее, а точность (Precision) 0.583099 наивысшая.</b></span></div>

# %% [markdown]
# #### Исследование модели случайного леса - RandomForestClassifier

# %%
# %%time
# Формирование и обучение модели случайного леса
# с выводом времени обучения
model_upsampled_forest = model_select(
    RandomForestClassifier,
    features_train_upsampled,
    target_train_upsampled,
    features_valid,
    target_valid,
    24,
    13,
    1
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.999644128113879 при значениях параметров:
# - количество деревьев в лесу: 12
# - максимальная глубина дерева: 23
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.9995886466474702 при значениях параметров:
# - количество деревьев в лесу: 12
# - максимальная глубина дерева: 23
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 0.999644128113879
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.857 при значениях параметров:
# ...

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '1'
action_upsampled_forest = [
    ['увеличение класса "1" в 2 раза', 0.6044568245125348, 0.5945205479452055, 0.6147308781869688, 0.8484596372167064, 0.858, 0.935966735966736],
    ['увеличение класса "1" в 3 раза', 0.6041923551171394, 0.6712328767123288, 0.5493273542600897, 0.8520480918269031, 0.8395, 0.861447212336892],
    ['увеличение класса "1" в 4 раза', 0.5901201602136181, 0.6054794520547945, 0.5755208333333334, 0.8326153072766118, 0.8465, 0.9918092275790565]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '1'
df_upsampled_forest = pd.DataFrame(data=action_upsampled_forest, columns=columns_model)
df_upsampled_forest
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  увеличение класса "1" в 2 раза  0.604457      0.594521         0.614731
# 1  увеличение класса "1" в 3 раза  0.604192      0.671233         0.549327
# 2  увеличение класса "1" в 4 раза  0.590120      0.605479         0.575521
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.848460          0.8580        0.935967
# 1       0.852048          0.8395        0.861447
# 2       0.832615          0.8465        0.991809

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.3.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Все действия привели к достижению размера среднего гармонического (F1) до требуемого 0.59 и выше.\
#     2. Наибольшее значение среднего гармонического (F1) 0.604457 при увеличении обучающих выборок в 2 раза.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.848460, полноты (Recall) 0.594521, точности (Precision) 0.614731.\
#     3. При увеличении обучающих выборок в 3 раза значения среднего гармонического (F1) 0.604192 и площади (AUC-ROC) под кривой ROC 0.852048.\
#     При этом значение полноты (Recall) 0.671233, а точность (Precision) 0.549327.</b></span></div>

# %% [markdown]
# #### Исследование модели логистической регрессии - LogisticRegression

# %%
# %%time
# Формирование и обучение модели логистической регрессии
# с решателем solver='lbfgs' с выводом времени обучения
model_upsampled_logistic = model_select(
    LogisticRegression,
    features_train_upsampled,
    target_train_upsampled,
    features_valid,
    target_valid,
    iter_start=22,
    iter_treshold=100
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.7131156039398652 при значениях параметров:
# - максимальное количество итераций: 22
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.7126985775101234 при значениях параметров:
# - максимальное количество итераций: 22
# - текущая правильность (accuracy) на обучающей выборке: 0.7131156039398652
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.7095 при значениях параметров:
# - максимальное количество итераций: 22
# - текущее значение полноты (Recall) на валидационной выборке: 0.6958904109589041
# ...

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '1'
action_upsampled_logistic = [
    ['увеличение класса "1" в 2 раза', 0.4388185654008439, 0.4273972602739726, 0.4508670520231214, 0.764718696326086, 0.8005, 0.7413721413721414],
    ['увеличение класса "1" в 3 раза', 0.4524590163934426, 0.5671232876712329, 0.37636363636363634, 0.7662619915378494, 0.7495, 0.7149466192170818],
    ['увеличение класса "1" в 4 раза', 0.46648301193755737, 0.6958904109589041, 0.35082872928176795, 0.7671702065267479, 0.7095, 0.7131156039398652]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '1'
df_upsampled_logistic = pd.DataFrame(data=action_upsampled_logistic, columns=columns_model)
df_upsampled_logistic
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  увеличение класса "1" в 2 раза  0.438819      0.427397         0.450867
# 1  увеличение класса "1" в 3 раза  0.452459      0.567123         0.376364
# 2  увеличение класса "1" в 4 раза  0.466483      0.695890         0.350829
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.764719          0.8005        0.741372
# 1       0.766262          0.7495        0.714947
# 2       0.767170          0.7095        0.713116

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.3.4:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Ни одно действие не привело к достижению размера среднего гармонического (F1) до требуемого 0.59.\
#     2. Наибольшие значения среднего гармонического (F1) 0.466483 и площади (AUC-ROC) под кривой ROC 0.767170 наблюдаются при увеличении обучающих выборок в 4 раза.\
#     При этом значение полноты (Recall) 0.695890 наибольшее, а точность (Precision) 0.350829	 наинизшая.</b></span></div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Лучшие показатели метрик качества у модели случайного леса model_upsampled_forest.\
#     2. Наибольшее значение среднего гармонического (F1) 0.604457 при увеличении обучающих выборок в 2 раза.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.848460, полноты (Recall) 0.594521, точности (Precision) 0.614731.\
#     3. При увеличении обучающих выборок в 3 раза значения среднего гармонического (F1) 0.604192 и площади (AUC-ROC) под кривой ROC 0.852048.\
#     При этом значение полноты (Recall) 0.671233, а точность (Precision) 0.549327.\
#     4. Так как основной задачей является сохранение текущих клиентов, а не привлечение новых, то при равных значениях среднего гармонического (F1) предпочтение отдаю модели с увеличенными обучающими выбороками в 3 раза, которая имеет большую полноту (Recall) 0.671233, чтобы охватить большую долю клиентов, собирающихся расторгнуть договор. Из-за более низкой точности (Precision) 0.549327 в профилактических целях рассылку выгодных условий получат 45% клиентов, которые не собираются уходить.</b></span></div>

# %% [markdown]
# ### Исследование результатов уменьшения обучающих данных

# %% [markdown]
# #### Формирование уменьшенных обучающих данных (downsampling)

# %%
# Уменьшение выборки признаков, относящихся к классу 0,
# с дальнейшим объединением с выборкой класса 1
features_train_downsampled = pd.concat(
    [features_train_0.sample(frac=.508, random_state=777)] + [features_train_1]
)
target_train_downsampled = pd.concat(
    [target_train_0.sample(frac=.508, random_state=777)] + [target_train_1]
)

# %%
# Перемешивание данных в обучающих выборках
features_train_downsampled, target_train_downsampled = shuffle(
    features_train_downsampled,
    target_train_downsampled,
    random_state=777
)

# %%
# Вывод уникальных значений в target_train_downsampled
# по долям в процентах
target_train_downsampled.value_counts(normalize=True)
# Out:
# 0    0.666758
# 1    0.333242
# Name: exited, dtype: float64

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.4.1:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>Уменьшение размера и перемешивание выборок с классом '0' выполняется корректно.</b></span></div>

# %% [markdown]
# #### Исследование модели решающего дерева - DecisionTreeClassifier

# %%
# %%time
# Формирование и обучение модели решающего дерева
# с выводом времени обучения
model_downsampled_tree = model_select(
    DecisionTreeClassifier,
    features_train_downsampled,
    target_train_downsampled,
    features_valid,
    target_valid,
    26
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 20
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 1.0 при значениях параметров:
# - максимальная глубина дерева: 20
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 1.0
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.8415 при значениях параметров:
# - максимальная глубина дерева: 3
# - минимальное количество выборок в листе: 1
# ...

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '0'
action_downsampled_tree = [
    ['уменьшение класса "0" до 25.4%', 0.5690376569037656, 0.7452054794520548, 0.4602368866328257, 0.8389753257090192, 0.794, 0.8094650205761317],
    ['уменьшение класса "0" до 44.4%', 0.5632333767926988, 0.5917808219178082, 0.5373134328358209, 0.8242386158937622, 0.8325, 0.8146706586826348],
    ['уменьшение класса "0" до 50.8%', 0.5651041666666666, 0.5945205479452055, 0.5384615384615384, 0.8296887436638599, 0.833, 0.8255622600109709],
    ['уменьшение класса "0" до 76.2%', 0.585949177877429, 0.536986301369863, 0.6447368421052632, 0.8303757697624732, 0.8615, 0.8508537337996297]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '0'
df_downsampled_tree = pd.DataFrame(data=action_downsampled_tree, columns=columns_model)
df_downsampled_tree
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  уменьшение класса "0" до 25.4%  0.569038      0.745205         0.460237
# 1  уменьшение класса "0" до 44.4%  0.563233      0.591781         0.537313
# 2  уменьшение класса "0" до 50.8%  0.565104      0.594521         0.538462
# 3  уменьшение класса "0" до 76.2%  0.585949      0.536986         0.644737
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.838975          0.7940        0.809465
# 1       0.824239          0.8325        0.814671
# 2       0.829689          0.8330        0.825562
# 3       0.830376          0.8615        0.850854

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.4.2:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Ни одно действие не привело к достижению размера среднего гармонического (F1) до требуемого 0.59.\
#     2. Наибольшие значения среднего гармонического (F1) 0.585949 наблюдается при уменьшении обучающих выборок до 76.2%.\
#     При этом значение полноты (Recall) 0.536986 наименьшее, точности (Precision) 0.644737 наивысшее, а площадь (AUC-ROC) под кривой ROC 0.830376 .</b></span></div>

# %% [markdown]
# ####  Исследование модели случайного леса - RandomForestClassifier

# %%
# %%time
# Формирование и обучение модели случайного леса
# с выводом времени обучения
model_downsampled_forest = model_select(
    RandomForestClassifier,
    features_train_downsampled,
    target_train_downsampled,
    features_valid,
    target_valid,
    24,
    13,
    1
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.9915697674418604 при значениях параметров:
# - количество деревьев в лесу: 11
# - максимальная глубина дерева: 21
# - минимальное количество выборок в листе: 1
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.9879717959352966 при значениях параметров:
# - количество деревьев в лесу: 11
# - максимальная глубина дерева: 21
# - минимальное количество выборок в листе: 1
# - текущая правильность (accuracy) на обучающей выборке: 0.9915697674418604
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.8615 при значениях параметров:
# ...

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '0'
action_downsampled_forest = [
    ['уменьшение класса "0" до 25.4%', 0.5568065506653019, 0.7452054794520548, 0.4444444444444444, 0.846901260944242, 0.7835, 0.8646090534979424],
    ['уменьшение класса "0" до 44.4%', 0.5987261146496814, 0.6438356164383562, 0.5595238095238095, 0.8528850906958234, 0.8425, 0.848502994011976],
    ['уменьшение класса "0" до 50.8%', 0.6061452513966481, 0.5945205479452055, 0.6182336182336182, 0.8524795777303004, 0.859, 0.8307734503565551],
    ['уменьшение класса "0" до 76.2%', 0.608695652173913, 0.5561643835616439, 0.6721854304635762, 0.8391219471325039, 0.8695, 0.9154494959884797]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '0'
df_downsampled_forest = pd.DataFrame(data=action_downsampled_forest, columns=columns_model)
df_downsampled_forest
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  уменьшение класса "0" до 25.4%  0.556807      0.745205         0.444444
# 1  уменьшение класса "0" до 44.4%  0.598726      0.643836         0.559524
# 2  уменьшение класса "0" до 50.8%  0.606145      0.594521         0.618234
# 3  уменьшение класса "0" до 76.2%  0.608696      0.556164         0.672185
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.846901          0.7835        0.864609
# 1       0.852885          0.8425        0.848503
# 2       0.852480          0.8590        0.830773
# 3       0.839122          0.8695        0.915449

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.4.3:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Большинство понижений привели к достижению размера среднего гармонического (F1) до требуемого 0.59 и выше.\
#     2. Наибольшее значение среднего гармонического (F1) 0.608696 при уменьшении обучающих выборок до 76.2%.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.839122, полноты (Recall) 0.556164, точности (Precision) 0.672185.\
#     3. При уменьшении обучающих выборок до 50.8% значения среднего гармонического (F1) 0.606145 и площади (AUC-ROC) под кривой ROC 0.852480.\
#     При этом значение полноты (Recall) 0.594521, а точность (Precision) 0.618234.</b></span></div>

# %% [markdown]
# #### Исследование модели логистической регрессии - LogisticRegression

# %%
# %%time
# Формирование и обучение модели логистической регрессии
# с решателем solver='lbfgs' с выводом времени обучения
model_downsampled_logistic = model_select(
    LogisticRegression,
    features_train_downsampled,
    target_train_downsampled,
    features_valid,
    target_valid,
    iter_start=22,
    iter_treshold=100
)
# Out:
# Лучшее значение правильности (accuracy) на обучающей выборке: 0.7365269461077845 при значениях параметров:
# - максимальное количество итераций: 22
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение среднего гармонического (F1) на обучающей выборке: 0.5825426944971537 при значениях параметров:
# - максимальное количество итераций: 22
# - текущая правильность (accuracy) на обучающей выборке: 0.7365269461077845
# -------------------------------------------------------------------------------------------------------------------
# -------------------------------------------------------------------------------------------------------------------
# Лучшее значение правильности (accuracy) на валидационной выборке: 0.789 при значениях параметров:
# - максимальное количество итераций: 22
# - текущее значение полноты (Recall) на валидационной выборке: 0.473972602739726
# ...

# %%
# Создание списка списков с метриками качества
# на разных размерах класса '0'
action_downsampled_logistic = [
    ['уменьшение класса "0" до 25.4%', 0.4605621033544878, 0.6958904109589041, 0.34417344173441733, 0.7659302082024213, 0.7025, 0.7160493827160493],
    ['уменьшение класса "0" до 44.4%', 0.4505208333333333, 0.473972602739726, 0.4292803970223325, 0.7633932386577855, 0.789, 0.7365269461077845],
    ['уменьшение класса "0" до 50.8%', 0.4425770308123249, 0.4328767123287671, 0.45272206303724927, 0.7634686439612919, 0.801, 0.7443773998902907],
    ['уменьшение класса "0" до 76.2%', 0.3696027633851468, 0.29315068493150687, 0.5, 0.7624934020359431, 0.8175, 0.7800864019749023]
]

# %%
# Формирование и вывод на экран датафрейма с метриками
# качества на разных размерах класса '0'
df_downsampled_logistic = pd.DataFrame(data=action_downsampled_logistic, columns=columns_model)
df_downsampled_logistic
# Out:
#                            action  f1_valid  recall_valid  precision_valid  \
# 0  уменьшение класса "0" до 25.4%  0.460562      0.695890         0.344173
# 1  уменьшение класса "0" до 44.4%  0.450521      0.473973         0.429280
# 2  уменьшение класса "0" до 50.8%  0.442577      0.432877         0.452722
# 3  уменьшение класса "0" до 76.2%  0.369603      0.293151         0.500000
#
#    auc_roc_valid  accuracy_valid  accuracy_train
# 0       0.765930          0.7025        0.716049
# 1       0.763393          0.7890        0.736527
# 2       0.763469          0.8010        0.744377
# 3       0.762493          0.8175        0.780086

# %% [markdown]
# <div class="alert alert-block alert-warning"><span style="color:green"><font size="3" face="Arial"><b>Промежуточные выводы 4.4.4:<b/></span>
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Ни одно действие не привело к достижению размера среднего гармонического (F1) до требуемого 0.59.\
#     2. Наибольшие значения среднего гармонического (F1) 0.460562 и площади (AUC-ROC) под кривой ROC 0.765930 наблюдаются при уменьшении обучающих выборок до 25.4%.\
#     При этом значение полноты (Recall) 0.695890 наибольшее, а точность (Precision) 0.344173 наинизшая.</b></span></div>

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Лучшие показатели метрик качества у модели случайного леса model_upsampled_forest.\
#     2. Наибольшее значение среднего гармонического (F1) 0.608696 при уменьшении обучающих выборок до 76.2%.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.839122, полноты (Recall) 0.556164, точности (Precision) 0.672185.\
#     3. При уменьшении обучающих выборок до 50.8% значения среднего гармонического (F1) 0.606145 и площади (AUC-ROC) под кривой ROC 0.852480.\
#     При этом значение полноты (Recall) 0.594521, а точность (Precision) 0.618234.\
#     4. Так как основной задачей является сохранение текущих клиентов, а не привлечение новых, то при равных значениях среднего гармонического (F1) предпочтение отдаю модели с уменьшением обучающих выборок до 50.8%, которая имеет большую полноту (Recall) 0.594521, чтобы охватить большую долю клиентов, собирающихся расторгнуть договор. Из-за более низкой точности (Precision) 0.618234 в профилактических целях рассылку выгодных условий получат 38% клиентов, которые не собираются уходить.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Супер:</b> По модельной части замечаний нет. Все сделано четко! 💪 Молодец, что не ограничился заданием Практикума и дополнительно добавил и от себя
# </div>

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# **Тестирование проведу на модели с лучшими значениями F1, Recall и Precision - model_upsampled_forest**

# %% [markdown]
# #### Тестирование модели model_upsampled_forest

# %%
# Формирование переменной с предсказаниями по тестовой
# выборке признаков (вопросов) моделью model_upsampled_forest
predictions_test_forest2 = model_upsampled_forest.predict(features_test)

# %%
# Формирование матрицы ошибок cm_upsampled_forest
cm_upsampled_forest = confusion_matrix(
    y_true=target_test,
    y_pred=predictions_test_forest2,
    labels=model_upsampled_forest.classes_,
    normalize='true'
)

# %%
# Вывод на экран матрицы ошибок cm_upsampled_forest
ConfusionMatrixDisplay(
    confusion_matrix=cm_upsampled_forest,
    display_labels=model_upsampled_forest.classes_
).plot()
plt.show()

# %%
# Вывод отчёта по метрикам качества
print(classification_report(target_test, predictions_test_forest2, target_names=['class 0', 'class 1']))
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.89      0.86      0.88      1543
#      class 1       0.59      0.65      0.62       457
#
#     accuracy                           0.81      2000
#    macro avg       0.74      0.76      0.75      2000
# weighted avg       0.82      0.81      0.82      2000

# %%
# Вычисление вероятности классов на
# тестовой выборке
probabilities_test = model_upsampled_forest.predict_proba(features_test)

# %%
# Вычисление и вывод на экран площади под
# ROC-кривой по вероятности класса '1'
auc_roc_test = roc_auc_score(target_test, probabilities_test[:, 1])
auc_roc_test
# Out:
# 0.8533264506467408

# %% [markdown]
# #### Вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>1. Результаты на тестовой выборке схожи с валидационной.\
#     2. Увеличилось значение среднего гармонического (F1) до 0.62.\
#     При этом увеличились значения площади (AUC-ROC) под кривой ROC до 0.8533264506467408, точности (Precision) до 0.59.\
#     Полнота (Recall) немного уменьшилась до 0.65.\
#     3. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 86% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 65%.\
#     4. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 35% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 14%.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Молодец:</b> Отличный результат!)
# </div>

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# <div class="alert alert-block alert-warning">
#
# <span style="color:steelblue"><font size="3" face="Courier"><b>В ходе выполнения проекта проанализировал предоставленные данные, на основании которых обучил три модели с изучением метрик качества и контрольным тестированием, выбрав лучшую модель.\
#     \
#     1. Названия колонок написаны с нарушением змеиного стиля.\
#     2. Обнаружены и заполнены пропуски в колонке 'Tenure' в количестве 909 шт.\
#     3. Аномалии и явные дубликаты не обнаружены.\
#     4. Осуществил кодирование категориальных данных в численные.\
#     5. Выполнил декомпозицию, масштабирование исходного датафрейма и сформировал обучающую, валидационную и тестовую выборки.\
#     6. Создал функцию 'model_select()', которая обучает и формирует любую из трёх моделей ML (DecisionTreeClassifier, RandomForestClassifier, LogistisRegression), выводит значения параметров обучения, при которых модель переобучается, а также значения параметров и метрик качества на валидационных выборках.\
#     \
#     7. Результаты исследования созданных моделей:\
#     7.1. Из трёх моделей лучшие значения метрик качества на валидационной выборке имеет случайный лес (RandomForestClassifier) при 10 деревьях глубиной дерева 13 с количеством выборок в листе 10.\
#     Значение правильности (accuracy) при этих параметрах на валидационной выборке составляет 0.875, а текущая правильность (accuracy) на обучающей выборке 0.8831666666666667.\
#     При этом полнота (Recall - доля истинно-положительных ответов) на валидационной выборке 0.4794520547945205, точность (Precision - доля истинно-положительных ответов с учётом ошибочных) 0.7446808510638298.\
#     Площадь (AUC-ROC) под ROC-кривой 0.8493686900423107 значительно больше, чем у случайной модели 0.5.\
#     7.2. Лучшее значение среднего гармонического (F1) равняется 0.5958132045088567 и достигается при 8 деревьях глубиной дерева 11 и количестве выборок в листе 3.\
#     Полнота (Recall - доля истинно-положительных ответов) на валидационной выборке выросла до 0.5068493150684932, но точность (Precision - доля истинно-положительных ответов с учётом ошибочных) понизилась до 0.72265625.\
#     Площадь (AUC-ROC) под ROC-кривой составляет 0.8549352771144904, что больше, чем у моделей DecisionTreeClassifier и LogistisRegression.\
#     Модель немного переобучается, и показывает текущие правильности (accuracy) на валидационной выборке 0.8745 и на обучающей выборке 0.9028333333333334.\
#     7.3. На втором месте решающее дерево (DecisionTreeClassifier).\
#     7.4. На третьем месте модель логистической регрессии (LogistisRegression).\
#     \
#     8. Проверка моделей на тестовой выборке показала следующие результаты:\
#     8.1. Из трёх моделей лучшее значение среднего гармонического (F1) на тестовой выборке имеет случайный лес (RandomForestClassifier) - 0.60.\
#     8.2. На втором месте решающее дерево (DecisionTreeClassifier) со значением среднего гармонического (F1) на тестовой выборке 0.59.\
#     8.3. На третьем месте модель логистической регрессии (LogistisRegression). Значение среднего гармонического (F1) на тестовой выборке 0.31.\
#     \
#     9. В ходе проверки модели на адекватность составлены следующие выводы:\
#     9.1. Модель model_random_forest правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 95% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 50%.\
#     9.2. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 50% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 5%.\
#     9.3. После составления базовой модели с фиктивными классификаторами (DummyClassifier), которая делает прогнозы, не пытаясь найти закономерности в данных, был выявлен дисбаланс классов, связанный с тем, что в наборе данных обучающей базы гораздо больше клиентов (80%), являющихся пользователями услуг банка, чем тех, кто расторгнул договор (20%), поэтому фиктивный классификатор предсказывает лучше текущих клиентов банка.\
# Из этого следует, что model_random_forest хорошо определяет клиентов, являющихся пользователями услуг банка, а хуже - расторгнувших договор.\
#     9.4. После создания с помощью SMOTENC синтетическихх выборок, похожих на реальные данные, был устранён дисбаланс классов в данных.\
#     9.5. Повторное обучение обеих моделей на синтетических выборках и дальнейшее сравнение матриц ошибок показало, что модель model_random_forest_sm фактически увеличила свои показатели по количеству верных ответов на 19% (с 50% до 69%), превысив показатель базовой модели model_dummy_sm с фиктивными классификаторами на 20%.\
#     9.6. Исходя из выполненной проверки модели на адекватность, сделал вывод, что у обученной модели обученной модели model_random_forest необходимо улучшать метрики качества Recall (полнота), Precision (точность) и F1 (среднее гармоническое). Для текущей бизнес-задачи она мало подходит.\
#     Для улучшения показателей метрик качества необходимо устранить дисбаланс классов, увеличивая в обучающей выборке долю данных, относящихся к целевому классу 1.0 - клиенты, расторгнувшие договор; либо уменьшая в обучающей выборке долю данных, относящихся к целевому классу 0.0 - клиенты, являющиеся пользователями услуг банка.\
#     \
#     10. Результаты борьбы с дисбалансом:\
#     10.1. После задания параметру 'class_weight' значения 'balanced' среднее гармоническое (F1) составило 0.5944517833553501, что незначительно ниже, чем с несбалансированным вариантом.\
#     Площадь (AUC-ROC) под кривой ROC понизилась до 0.8393699467973692.\
#     При этом значение полноты (Recall) увеличилось до 0.6164383561643836, а точность (Precision) понизилась до 0.5739795918367347.\
#     Модель немного переобучилась.\
#     \
#     10.2. При использовании увеличенных обучающих данных с классом '1':\
#     10.2.1. Лучшие показатели метрик качества у модели случайного леса model_upsampled_forest.\
#     10.2.2. Наибольшее значение среднего гармонического (F1) 0.604457 при увеличении обучающих выборок в 2 раза.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.848460, полноты (Recall) 0.594521, точности (Precision) 0.614731.\
#     10.2.3. При увеличении обучающих выборок в 3 раза значения среднего гармонического (F1) 0.604192 и площади (AUC-ROC) под кривой ROC 0.852048.\
#     При этом значение полноты (Recall) 0.671233, а точность (Precision) 0.549327.\
#     10.2.4. Так как основной задачей является сохранение текущих клиентов, а не привлечение новых, то при равных значениях среднего гармонического (F1) предпочтение отдаю модели с увеличенными обучающими выбороками в 3 раза, которая имеет большую полноту (Recall) 0.671233, чтобы охватить большую долю клиентов, собирающихся расторгнуть договор. Из-за более низкой точности (Precision) 0.549327 в профилактических целях рассылку выгодных условий получат 45% клиентов, которые не собираются уходить.\
#     \
#     10.3. При использовании уменьшенных обучающих данных с классом '0':\
#     10.3.1. Лучшие показатели метрик качества у модели случайного леса model_downsampled_forest.\
#     10.3.2. Наибольшее значение среднего гармонического (F1) 0.608696 при уменьшении обучающих выборок до 76.2%.\
#     При этом значения площади (AUC-ROC) под кривой ROC 0.839122, полноты (Recall) 0.556164, точности (Precision) 0.672185.\
#     10.3.3. При уменьшении обучающих выборок до 50.8% значения среднего гармонического (F1) 0.606145 и площади (AUC-ROC) под кривой ROC 0.852480.\
#     При этом значение полноты (Recall) 0.594521, а точность (Precision) 0.618234.\
#     10.3.4. Так как основной задачей является сохранение текущих клиентов, а не привлечение новых, то при равных значениях среднего гармонического (F1) предпочтение отдаю модели с уменьшением обучающих выборок до 50.8%, которая имеет большую полноту (Recall) 0.594521, чтобы охватить большую долю клиентов, собирающихся расторгнуть договор. Из-за более низкой точности (Precision) 0.618234 в профилактических целях рассылку выгодных условий получат 38% клиентов, которые не собираются уходить.\
#     \
#     11. Контрольное тестирование модели model_upsampled_forest  дало следующие результаты:\
#     11.1. Результаты на тестовой выборке схожи с валидационной.\
#     11.2. Увеличилось значение среднего гармонического (F1) до 0.62.\
#     При этом увеличились значения площади (AUC-ROC) под кривой ROC до 0.8533264506467408, точности (Precision) до 0.59.\
#     Полнота (Recall) немного уменьшилась до 0.65.\
#     11.3. Модель правильно предсказала клиентов, являющихся пользователями услуг банка (TN - True Negative (истинно-отрицательное решение), верхний левый квадрант) в 86% случаев, а прогнозы для клиентов, расторгнувших договор (TP - True Positive (истинно-положительное решение), нижний правый квадрант) — в 65%.\
#     11.4. При этом модель предсказала отрицательный результат, но на самом деле он положительный (FN - False Negative (ложноотрицательное решение)) в 35% случаев, и предсказала положительный результат, а на самом деле он отрицательный (FP - False Positive (ложноположительное решение)) - в 14%.\
#     \
#     12. Исходя из результатов обучения моделей и анализа метрик качества (F1 (среднее гармоническое), Recall (полнота), Precision (точность), Accuracy (правильность) и AUC-ROC (площадь под кривой ROC)), делаю вывод, что лучшей моделью является model_upsampled_forest с увеличенной выборкой с классом '1' в 3 раза. Качество обученной модели довольно хорошее.\
#     При возникновении необходимости увеличения точности (Precision) предсказания можно оставить текущий баланс классов в модели model_random_forest.</b></span></div>

# %% [markdown]
# <div class="alert alert-block alert-success">
# <b>Супер:</b> Информативный вывод как вишенка на торте )
# </div>

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# Поставьте 'x' в выполненных пунктах. Далее нажмите Shift+Enter.

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
